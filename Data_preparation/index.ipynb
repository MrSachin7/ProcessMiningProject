# %%
import pandas as pd
import ast

# %%
events_world_cup =pd.read_csv('../events_World_Cup.csv')
teams = pd.read_csv('../teams.csv')
tags2name = pd.read_csv('../tags2name.csv')
playerrank = pd.read_csv('../playerank.csv')
players = pd.read_csv('../players.csv')
matches_world_cup = pd.read_csv('../matches_World_Cup.csv')

# %% [markdown]
# Lets filter the unrequired columns

# %%
events_world_cup = events_world_cup[['subEventName', 'tags', 'playerId', 'matchId', 'eventName', 'teamId', 'eventSec', 'matchPeriod']]
players = players[['wyId', 'shortName']]
tags2name = tags2name[['Tag', 'Description']]
teams = teams[['wyId', 'officialName', 'type']]
playerrank = playerrank[['playerId', 'roleCluster']]

# %% [markdown]
# Start filtering the data

# %%
# Only national teams
teams = teams[teams['type'] == 'national']

# Only matches where France has played.
matches_world_cup = matches_world_cup[matches_world_cup['label'].str.contains("France")]

# Only events from the matches where France has played.
events_world_cup = events_world_cup[events_world_cup['matchId'].isin(matches_world_cup['wyId'])]

events_world_cup
# Out:
#        subEventName            tags  playerId  matchId           eventName  \
# 18813   Simple pass  [{'id': 1801}]    238055  2057966                Pass
# 18814     High pass  [{'id': 1802}]     61395  2057966                Pass
# 18815      Throw in  [{'id': 1801}]    340646  2057966           Free Kick
# 18816   Simple pass  [{'id': 1801}]    209091  2057966                Pass
# 18817        Launch  [{'id': 1802}]    340646  2057966                Pass
# ...             ...             ...       ...      ...                 ...
# 101751    High pass  [{'id': 1802}]     69396  2058017                Pass
# 101752    Clearance  [{'id': 1802}]      3309  2058017  Others on the ball
# 101753     Throw in  [{'id': 1801}]     69968  2058017           Free Kick
# 101754  Simple pass  [{'id': 1801}]      3476  2058017                Pass
# 101755        Touch              []     14812  2058017  Others on the ball
#
#         teamId     eventSec matchPeriod
# 18813     8493     1.435354          1H
# 18814     8493     3.978396          1H
# 18815     4418    15.608867          1H
# 18816     4418    16.385084          1H
# 18817     4418    17.214485          1H
# ...        ...          ...         ...
# 101751    9598  2964.715715          2H
# 101752    4418  2967.926784          2H
# 101753    9598  2972.985039          2H
# 101754    9598  2978.301867          2H
# 101755    9598  2979.084611          2H
#
# [10843 rows x 8 columns]

# %%
# Merge match name
data = pd.merge(events_world_cup, teams, left_on='teamId', right_on='wyId')
data
# Out:
#       subEventName                         tags  playerId  matchId  \
# 0      Simple pass               [{'id': 1801}]    238055  2057966
# 1        High pass               [{'id': 1802}]     61395  2057966
# 2        Head pass               [{'id': 1802}]     61425  2057966
# 3        High pass               [{'id': 1801}]     62389  2057966
# 4         Air duel  [{'id': 701}, {'id': 1802}]     16151  2057966
# ...            ...                          ...       ...      ...
# 10838        Touch                           []     69396  2058017
# 10839    High pass               [{'id': 1802}]     69396  2058017
# 10840     Throw in               [{'id': 1801}]     69968  2058017
# 10841  Simple pass               [{'id': 1801}]      3476  2058017
# 10842        Touch                           []     14812  2058017
#
#                 eventName  teamId     eventSec matchPeriod  wyId officialName  \
# 0                    Pass    8493     1.435354          1H  8493    Australia
# 1                    Pass    8493     3.978396          1H  8493    Australia
# 2                    Pass    8493    19.920463          1H  8493    Australia
# 3                    Pass    8493    26.371362          1H  8493    Australia
# 4                    Duel    8493    27.942092          1H  8493    Australia
# ...                   ...     ...          ...         ...   ...          ...
# 10838  Others on the ball    9598  2960.803153          2H  9598      Croatia
# 10839                Pass    9598  2964.715715          2H  9598      Croatia
# 10840           Free Kick    9598  2972.985039          2H  9598      Croatia
# 10841                Pass    9598  2978.301867          2H  9598      Croatia
# 10842  Others on the ball    9598  2979.084611          2H  9598      Croatia
#
#            type
# 0      national
# 1      national
# 2      national
# 3      national
# 4      national
# ...         ...
# 10838  national
# 10839  national
# 10840  national
# 10841  national
# 10842  national
#
# [10843 rows x 11 columns]

# %%
# Merge player name
data = pd.merge(data, players, left_on='playerId', right_on='wyId')
data
# Out:
#                  subEventName                                      tags  \
# 0                 Simple pass                            [{'id': 1801}]
# 1                 Simple pass                            [{'id': 1801}]
# 2      Ground loose ball duel               [{'id': 701}, {'id': 1802}]
# 3                   Head pass                            [{'id': 1801}]
# 4                    Air duel               [{'id': 701}, {'id': 1802}]
# ...                       ...                                       ...
# 10838             Simple pass                            [{'id': 1801}]
# 10839   Ground attacking duel  [{'id': 502}, {'id': 703}, {'id': 1801}]
# 10840             Simple pass                            [{'id': 1802}]
# 10841             Simple pass                            [{'id': 1801}]
# 10842   Ground defending duel               [{'id': 703}, {'id': 1801}]
#
#        playerId  matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0        238055  2057966      Pass    8493     1.435354          1H    8493
# 1        238055  2057966      Pass    8493   318.452504          1H    8493
# 2        238055  2057966      Duel    8493   622.800480          1H    8493
# 3        238055  2057966      Pass    8493  1089.881235          1H    8493
# 4        238055  2057966      Duel    8493  1310.158067          1H    8493
# ...         ...      ...       ...     ...          ...         ...     ...
# 10838     69411  2058017      Pass    9598  2888.451480          2H    9598
# 10839    135810  2058017      Duel    9598  2398.932619          2H    9598
# 10840    135810  2058017      Pass    9598  2400.002448          2H    9598
# 10841    135810  2058017      Pass    9598  2567.478676          2H    9598
# 10842    135810  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
# Merge tags

def map_tags_to_desc(tag_list):
    descriptions = []
    for tag in tag_list:
        tag_id = tag['id']
        description = tags2name.loc[tags2name['Tag'] == tag_id, 'Description'].values
        if len(description) > 0:
            descriptions.append(description[0])
    return descriptions

data['tags'] = data['tags'].apply(lambda x: map_tags_to_desc(ast.literal_eval(x)))
data
# Out:
#                  subEventName                              tags  playerId  \
# 0                 Simple pass                        [Accurate]    238055
# 1                 Simple pass                        [Accurate]    238055
# 2      Ground loose ball duel              [Lost, Not accurate]    238055
# 3                   Head pass                        [Accurate]    238055
# 4                    Air duel              [Lost, Not accurate]    238055
# ...                       ...                               ...       ...
# 10838             Simple pass                        [Accurate]     69411
# 10839   Ground attacking duel  [Free space left, Won, Accurate]    135810
# 10840             Simple pass                    [Not accurate]    135810
# 10841             Simple pass                        [Accurate]    135810
# 10842   Ground defending duel                   [Won, Accurate]    135810
#
#        matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0      2057966      Pass    8493     1.435354          1H    8493
# 1      2057966      Pass    8493   318.452504          1H    8493
# 2      2057966      Duel    8493   622.800480          1H    8493
# 3      2057966      Pass    8493  1089.881235          1H    8493
# 4      2057966      Duel    8493  1310.158067          1H    8493
# ...        ...       ...     ...          ...         ...     ...
# 10838  2058017      Pass    9598  2888.451480          2H    9598
# 10839  2058017      Duel    9598  2398.932619          2H    9598
# 10840  2058017      Pass    9598  2400.002448          2H    9598
# 10841  2058017      Pass    9598  2567.478676          2H    9598
# 10842  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
data = data.drop(columns=['playerId', 'teamId', 'type', 'wyId_y', 'wyId_x'])

# Replace matchId with match label
data = data.merge(matches_world_cup[['wyId', 'label']], left_on='matchId', right_on='wyId', how='left')

data['matchId'] = data['label']
data = data.drop(columns=['label', 'wyId'])

data = data.rename(columns=
                   {'officialName': 'Team',
                    'shortName': 'Player',
                    'matchId' : 'Match',
                    'eventName': 'Event',
                    'tags': 'Tags', 
                    'matchPeriod': 'MatchPeriod',
                    'eventSec': 'EventSec',
                    'subEventName': 'SubEvent'}
                    )
data
# Out:
#                      SubEvent                              Tags  \
# 0                 Simple pass                        [Accurate]
# 1                 Simple pass                        [Accurate]
# 2      Ground loose ball duel              [Lost, Not accurate]
# 3                   Head pass                        [Accurate]
# 4                    Air duel              [Lost, Not accurate]
# ...                       ...                               ...
# 10838             Simple pass                        [Accurate]
# 10839   Ground attacking duel  [Free space left, Won, Accurate]
# 10840             Simple pass                    [Not accurate]
# 10841             Simple pass                        [Accurate]
# 10842   Ground defending duel                   [Won, Accurate]
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
data['Tags'] = data['Tags'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
data
# Out:
#                      SubEvent                            Tags  \
# 0                 Simple pass                        Accurate
# 1                 Simple pass                        Accurate
# 2      Ground loose ball duel              Lost, Not accurate
# 3                   Head pass                        Accurate
# 4                    Air duel              Lost, Not accurate
# ...                       ...                             ...
# 10838             Simple pass                        Accurate
# 10839   Ground attacking duel  Free space left, Won, Accurate
# 10840             Simple pass                    Not accurate
# 10841             Simple pass                        Accurate
# 10842   Ground defending duel                   Won, Accurate
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
grouped  = data.groupby('Match').size().reset_index(name='count')

# Data per match
grouped
# Out:
#                        Match  count
# 0    Denmark - France, 0 - 0   1581
# 1  France - Argentina, 4 - 3   1426
# 2  France - Australia, 2 - 1   1514
# 3    France - Belgium, 1 - 0   1588
# 4    France - Croatia, 4 - 2   1459
# 5       France - Peru, 1 - 0   1668
# 6    Uruguay - France, 0 - 2   1607

# %%
# All relevant french players
french_players = data[data['Team'] == 'France']['Player'].unique().tolist()
french_players
# Out:
# ['B. Pavard',
#  'C. Tolisso',
#  'R. Varane',
#  'H. Lloris',
#  'P. Pogba',
#  'S. Umtiti',
#  'A. Griezmann',
#  'N. Kant\\u00e9',
#  'K. Mbapp\\u00e9',
#  'L. Hern\\u00e1ndez',
#  'O. Demb\\u00e9l\\u00e9',
#  'N. Fekir',
#  'O. Giroud',
#  'B. Matuidi',
#  "S. N'Zonzi",
#  'D. Sidib\\u00e9',
#  'P. Kimpembe',
#  'T. Lemar',
#  'S. Mandanda',
#  'B. Mendy',
#  'F. Thauvin']

# %%
# Manually map the players to their respective postions
player_position_mapping = {
    'B. Pavard': 'RB',
    'C. Tolisso': 'CM',
    'R. Varane': 'CB',
    'H. Lloris': 'GKP',
    'P. Pogba': 'CM',
    'S. Umtiti': 'CB',
    'A. Griezmann': 'AM',
    'N. Kant\\u00e9': 'CDM',
    'K. Mbapp\\u00e9': 'CF',
    'L. Hern\\u00e1ndez': 'LB',
    'O. Demb\\u00e9l\\u00e9': 'RW',
    'N. Fekir': 'AM',
    'O. Giroud': 'CF',
    'B. Matuidi': 'LM',
    "S. N'Zonzi": 'CM',
    'D. Sidibé': 'RB',
    'P. Kimpembe': 'CB',
    'T. Lemar': 'LW',
    'S. Mandanda': 'GKP',
    'B. Mendy': 'LB',
    'F. Thauvin': 'RW',
    'D. Sidib\\u00e9': 'RB',
}

# Map the Position based on Player names
data['Position'] = data['Player'].map(player_position_mapping)

data[data['Team'] == 'France']
# Out:
#          SubEvent                              Tags  \
# 700      Throw in                          Accurate
# 701        Launch                      Not accurate
# 702   Simple pass                          Accurate
# 703   Simple pass                          Accurate
# 704   Simple pass                          Accurate
# ...           ...                               ...
# 6020  Simple pass                          Accurate
# 6021        Cross  Left foot, Blocked, Not accurate
# 6022     Throw in                          Accurate
# 6023  Simple pass                          Accurate
# 6024     Air duel                     Won, Accurate
#
#                           Match      Event     EventSec MatchPeriod    Team  \
# 700   France - Australia, 2 - 1  Free Kick    15.608867          1H  France
# 701   France - Australia, 2 - 1       Pass    17.214485          1H  France
# 702   France - Australia, 2 - 1       Pass    32.884277          1H  France
# 703   France - Australia, 2 - 1       Pass    54.866585          1H  France
# 704   France - Australia, 2 - 1       Pass    75.441589          1H  France
# ...                         ...        ...          ...         ...     ...
# 6020    Denmark - France, 0 - 0       Pass  2848.941221          2H  France
# 6021    Denmark - France, 0 - 0       Pass  2853.514985          2H  France
# 6022    Denmark - France, 0 - 0  Free Kick  2859.488457          2H  France
# 6023  France - Argentina, 4 - 3       Pass  2613.230156          2H  France
# 6024  France - Argentina, 4 - 3       Duel  2622.866067          2H  France
#
#           Player Position
# 700    B. Pavard       RB
# 701    B. Pavard       RB
# 702    B. Pavard       RB
# 703    B. Pavard       RB
# 704    B. Pavard       RB
# ...          ...      ...
# 6020    B. Mendy       LB
# 6021    B. Mendy       LB
# 6022    B. Mendy       LB
# 6023  F. Thauvin       RW
# 6024  F. Thauvin       RW
#
# [5325 rows x 9 columns]

# %%
data['SubEvent'] = data['SubEvent'].fillna('')

# %%
data["Status"] = "DRAW"

# France vs Australia

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

# Second goal conceded by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (17*60))
)
data.loc[mask, 'Status'] = 'DRAW'

mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (36*60))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Denmark is already prepopulated with draw

# France v Peru

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Peru', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (35*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Argentina

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (14*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (42*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (4*60 ))
)
data.loc[mask, 'Status'] = 'LOSING'

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'


#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (20*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# Uruguay vs France

#Scored
mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (40*60 ))
)

mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '2H'))
data.loc[mask, 'Status'] = 'LEADING'
# Belgium vs France

#Scored
mask = (
    data['Match'].str.contains('France - Belgium', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (7*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France - Croatia

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (20*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceeded
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (29*60))
)
data.loc[mask, 'Status'] = 'DRAW'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (39*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '2H') 
)
data.loc[mask, 'Status'] = 'LEADING'

# %% [markdown]
# ### Events before goals by given minute

# %%
def events_before_goal_by_minutes(data, opponent_team, minutes=1):  
    # Determine the times of all goals by France
    goal_times = data[
        data['Match'].str.contains(opponent_team, na=False) &
        (data['Tags'].str.contains('Goal,', na=False)) & 
        (data['Tags'].str.contains('Accurate', na=False))
    ][['EventSec', 'MatchPeriod']]
    
    if not goal_times.empty:
        events_before_goals = []
        
        for _, goal in goal_times.iterrows():
            goal_time = goal['EventSec']
            goal_period = goal['MatchPeriod']
            
            # Filter the events for the specified number of minutes before the goal (including the goal)
            events_before_goal = data[
                data['Match'].str.contains(opponent_team, na=False) &
                (data['MatchPeriod'] == goal_period) &
                (data['EventSec'] >= max(0, goal_time - minutes * 60)) & 
                (data['EventSec'] <= goal_time)
            ]
            
            events_before_goals.append(events_before_goal)
        
        # Concatenate all the events before each goal
        events_before_goal_df = pd.concat(events_before_goals, ignore_index=True)
        
        return events_before_goal_df.sort_values(by=['MatchPeriod', 'EventSec'])
    
    else:
        # Return an empty DataFrame if no goals are found
        return pd.DataFrame(columns=data.columns)

# %% [markdown]
# France - Denmark

# %%
events_denmark = events_before_goal_by_minutes(data, 'Denmark', minutes=1)
events_denmark
# Out:
# Empty DataFrame
# Columns: [SubEvent, Tags, Match, Event, EventSec, MatchPeriod, Team, Player, Position, Status]
# Index: []

# %% [markdown]
# France - Argentina

# %%
events_argentina = events_before_goal_by_minutes(data, 'Argentina', minutes=1)
events_argentina[events_argentina['Team'] == 'France']
# Out:
#                   SubEvent                                               Tags  \
# 23                 Penalty  Goal, Left foot, Position: Goal low center, Ac...
# 65   Ground defending duel                 Free space left, Neutral, Accurate
# 63                Air duel                                      Won, Accurate
# 64                Air duel                                      Won, Accurate
# 55                Air duel                                      Won, Accurate
# 56               Clearance                         Interception, Not accurate
# 57   Ground defending duel               Free space right, Lost, Not accurate
# 15                Air duel                                 Lost, Not accurate
# 4                Hand pass                                           Accurate
# 2              Simple pass                                           Accurate
# 14             Simple pass                                           Accurate
# 9              Simple pass                                           Accurate
# 0              Simple pass                                           Accurate
# 5                   Launch                                           Accurate
# 17  Ground loose ball duel                                      Won, Accurate
# 10             Simple pass                                           Accurate
# 7              Simple pass                                           Accurate
# 11             Simple pass                                           Accurate
# 8              Simple pass                                           Accurate
# 6              Simple pass                                           Accurate
# 3              Simple pass                                           Accurate
# 12                   Touch
# 13             Simple pass                                           Accurate
# 18              Smart pass                                  Through, Accurate
# 16                   Cross                          Left foot, High, Accurate
# 1                     Shot  Goal, Right foot, Opportunity, Position: Goal ...
# 31               Free Kick                                           Accurate
# 34             Simple pass                                           Accurate
# 25                   Touch
# 26             Simple pass                                           Accurate
# 29             Simple pass                                           Accurate
# 27             Simple pass                                           Accurate
# 24             Simple pass                                           Accurate
# 28             Simple pass                                           Accurate
# 32                   Touch
# 33             Simple pass                                           Accurate
# 30             Simple pass                                           Accurate
# 37                   Cross                                Left foot, Accurate
# 38                    Shot      Left foot, Blocked, Opportunity, Not accurate
# 35   Ground attacking duel                        Take on left, Won, Accurate
# 36                    Shot  Goal, Left foot, Opportunity, Position: Goal l...
# 41               Goal kick
# 43             Simple pass                                           Accurate
# 42             Simple pass                                           Accurate
# 45             Simple pass                                           Accurate
# 44             Simple pass                                           Accurate
# 48             Simple pass                                           Accurate
# 47             Simple pass                                   Assist, Accurate
# 46                    Shot  Goal, Right foot, Opportunity, Position: Goal ...
# 80                Air duel                                      Won, Accurate
# 76               Head pass                                       Not accurate
# 81  Ground loose ball duel                                  Neutral, Accurate
# 82  Ground loose ball duel                                 Lost, Not accurate
# 77   Ground defending duel                Free space left, Lost, Not accurate
# 83                   Touch                                       Interception
# 78   Ground defending duel                                 Lost, Not accurate
# 79                    Foul
#
#                         Match               Event     EventSec MatchPeriod  \
# 23  France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 65  France - Argentina, 4 - 3                Duel  2391.157729          1H
# 63  France - Argentina, 4 - 3                Duel  2412.972955          1H
# 64  France - Argentina, 4 - 3                Duel  2413.911393          1H
# 55  France - Argentina, 4 - 3                Duel   151.127278          2H
# 56  France - Argentina, 4 - 3  Others on the ball   151.562032          2H
# 57  France - Argentina, 4 - 3                Duel   153.960220          2H
# 15  France - Argentina, 4 - 3                Duel   650.822751          2H
# 4   France - Argentina, 4 - 3                Pass   655.959008          2H
# 2   France - Argentina, 4 - 3                Pass   660.094663          2H
# 14  France - Argentina, 4 - 3                Pass   661.281821          2H
# 9   France - Argentina, 4 - 3                Pass   663.789611          2H
# 0   France - Argentina, 4 - 3                Pass   665.437266          2H
# 5   France - Argentina, 4 - 3                Pass   672.381157          2H
# 17  France - Argentina, 4 - 3                Duel   674.966694          2H
# 10  France - Argentina, 4 - 3                Pass   679.933245          2H
# 7   France - Argentina, 4 - 3                Pass   682.189040          2H
# 11  France - Argentina, 4 - 3                Pass   685.259225          2H
# 8   France - Argentina, 4 - 3                Pass   687.631849          2H
# 6   France - Argentina, 4 - 3                Pass   690.806781          2H
# 3   France - Argentina, 4 - 3                Pass   694.837939          2H
# 12  France - Argentina, 4 - 3  Others on the ball   697.448353          2H
# 13  France - Argentina, 4 - 3                Pass   700.549707          2H
# 18  France - Argentina, 4 - 3                Pass   702.349985          2H
# 16  France - Argentina, 4 - 3                Pass   705.627015          2H
# 1   France - Argentina, 4 - 3                Shot   708.161917          2H
# 31  France - Argentina, 4 - 3           Free Kick  1049.105770          2H
# 34  France - Argentina, 4 - 3                Pass  1053.778440          2H
# 25  France - Argentina, 4 - 3  Others on the ball  1055.986914          2H
# 26  France - Argentina, 4 - 3                Pass  1059.374506          2H
# 29  France - Argentina, 4 - 3                Pass  1062.163056          2H
# 27  France - Argentina, 4 - 3                Pass  1065.000096          2H
# 24  France - Argentina, 4 - 3                Pass  1067.494307          2H
# 28  France - Argentina, 4 - 3                Pass  1070.782170          2H
# 32  France - Argentina, 4 - 3  Others on the ball  1072.821418          2H
# 33  France - Argentina, 4 - 3                Pass  1078.386281          2H
# 30  France - Argentina, 4 - 3                Pass  1080.811984          2H
# 37  France - Argentina, 4 - 3                Pass  1084.518196          2H
# 38  France - Argentina, 4 - 3                Shot  1085.701979          2H
# 35  France - Argentina, 4 - 3                Duel  1087.016026          2H
# 36  France - Argentina, 4 - 3                Shot  1088.431408          2H
# 41  France - Argentina, 4 - 3           Free Kick  1349.582519          2H
# 43  France - Argentina, 4 - 3                Pass  1355.363951          2H
# 42  France - Argentina, 4 - 3                Pass  1357.956948          2H
# 45  France - Argentina, 4 - 3                Pass  1362.232707          2H
# 44  France - Argentina, 4 - 3                Pass  1363.313748          2H
# 48  France - Argentina, 4 - 3                Pass  1366.156036          2H
# 47  France - Argentina, 4 - 3                Pass  1367.556927          2H
# 46  France - Argentina, 4 - 3                Shot  1369.345368          2H
# 80  France - Argentina, 4 - 3                Duel  2764.155813          2H
# 76  France - Argentina, 4 - 3                Pass  2773.122597          2H
# 81  France - Argentina, 4 - 3                Duel  2775.310341          2H
# 82  France - Argentina, 4 - 3                Duel  2776.642913          2H
# 77  France - Argentina, 4 - 3                Duel  2777.446266          2H
# 83  France - Argentina, 4 - 3  Others on the ball  2786.910112          2H
# 78  France - Argentina, 4 - 3                Duel  2801.447983          2H
# 79  France - Argentina, 4 - 3                Foul  2802.864070          2H
#
#       Team             Player Position   Status
# 23  France       A. Griezmann       AM     DRAW
# 65  France      N. Kant\u00e9      CDM  LEADING
# 63  France          B. Pavard       RB  LEADING
# 64  France           P. Pogba       CM  LEADING
# 55  France          R. Varane       CB     DRAW
# 56  France           P. Pogba       CM     DRAW
# 57  France         B. Matuidi       LM     DRAW
# 15  France  L. Hern\u00e1ndez       LB   LOSING
# 4   France          H. Lloris      GKP   LOSING
# 2   France          R. Varane       CB   LOSING
# 14  France     K. Mbapp\u00e9       CF   LOSING
# 9   France      N. Kant\u00e9      CDM   LOSING
# 0   France          B. Pavard       RB   LOSING
# 5   France          H. Lloris      GKP   LOSING
# 17  France          O. Giroud       CF   LOSING
# 10  France      N. Kant\u00e9      CDM   LOSING
# 7   France          S. Umtiti       CB   LOSING
# 11  France      N. Kant\u00e9      CDM   LOSING
# 8   France          S. Umtiti       CB   LOSING
# 6   France          H. Lloris      GKP   LOSING
# 3   France          R. Varane       CB   LOSING
# 12  France      N. Kant\u00e9      CDM   LOSING
# 13  France      N. Kant\u00e9      CDM   LOSING
# 18  France         B. Matuidi       LM   LOSING
# 16  France  L. Hern\u00e1ndez       LB   LOSING
# 1   France          B. Pavard       RB   LOSING
# 31  France          S. Umtiti       CB     DRAW
# 34  France      N. Kant\u00e9      CDM     DRAW
# 25  France          R. Varane       CB     DRAW
# 26  France          R. Varane       CB     DRAW
# 29  France           P. Pogba       CM     DRAW
# 27  France          R. Varane       CB     DRAW
# 24  France          B. Pavard       RB     DRAW
# 28  France          R. Varane       CB     DRAW
# 32  France          S. Umtiti       CB     DRAW
# 33  France          S. Umtiti       CB     DRAW
# 30  France           P. Pogba       CM     DRAW
# 37  France  L. Hern\u00e1ndez       LB     DRAW
# 38  France         B. Matuidi       LM     DRAW
# 35  France     K. Mbapp\u00e9       CF     DRAW
# 36  France     K. Mbapp\u00e9       CF     DRAW
# 41  France          H. Lloris      GKP  LEADING
# 43  France          S. Umtiti       CB  LEADING
# 42  France          H. Lloris      GKP  LEADING
# 45  France      N. Kant\u00e9      CDM  LEADING
# 44  France       A. Griezmann       AM  LEADING
# 48  France         B. Matuidi       LM  LEADING
# 47  France          O. Giroud       CF  LEADING
# 46  France     K. Mbapp\u00e9       CF  LEADING
# 80  France           N. Fekir       AM  LEADING
# 76  France         C. Tolisso       CM  LEADING
# 81  France           N. Fekir       AM  LEADING
# 82  France           N. Fekir       AM  LEADING
# 77  France         C. Tolisso       CM  LEADING
# 83  France           N. Fekir       AM  LEADING
# 78  France           P. Pogba       CM  LEADING
# 79  France           P. Pogba       CM  LEADING

# %%
events_argentina_france = events_argentina[events_argentina['Team'] == 'France']

# %% [markdown]
# Uruguay - France

# %%
events_uruguay = events_before_goal_by_minutes(data, 'Uruguay', minutes=1)
events_uruguay
# Out:
#                   SubEvent                                               Tags  \
# 1          Free kick cross                             Assist, High, Accurate
# 2                 Air duel                                 Lost, Not accurate
# 0                     Shot  Goal, Head/body, Opportunity, Position: Goal l...
# 14             Simple pass                             Fairplay, Not accurate
# 6              Simple pass                                           Accurate
# 7                   Launch                                           Accurate
# 18                Air duel                                      Won, Accurate
# 12                Air duel                                 Lost, Not accurate
# 4                Head pass                                       Not accurate
# 22            Acceleration                                           Accurate
# 23             Simple pass                                           Accurate
# 15  Ground loose ball duel                                 Lost, Not accurate
# 3   Ground loose ball duel                                      Won, Accurate
# 24   Ground defending duel                         Anticipated, Won, Accurate
# 13   Ground defending duel                                  Neutral, Accurate
# 25             Simple pass                                           Accurate
# 16             Simple pass                                           Accurate
# 19                   Touch                                        Missed ball
# 17             Simple pass                                           Accurate
# 20                   Touch
# 8    Ground defending duel                                      Won, Accurate
# 21   Ground defending duel                   Take on left, Lost, Not accurate
# 9             Acceleration                           Counter attack, Accurate
# 10             Simple pass                           Counter attack, Accurate
# 5              Simple pass                   Assist, Counter attack, Accurate
# 11                    Shot  Goal, Counter attack, Left foot, Opportunity, ...
#
#                       Match               Event     EventSec MatchPeriod  \
# 1   Uruguay - France, 0 - 2           Free Kick  2369.447264          1H
# 2   Uruguay - France, 0 - 2                Duel  2370.574308          1H
# 0   Uruguay - France, 0 - 2                Shot  2370.699238          1H
# 14  Uruguay - France, 0 - 2                Pass   911.317722          2H
# 6   Uruguay - France, 0 - 2                Pass   917.104962          2H
# 7   Uruguay - France, 0 - 2                Pass   920.558108          2H
# 18  Uruguay - France, 0 - 2                Duel   923.857204          2H
# 12  Uruguay - France, 0 - 2                Duel   923.882755          2H
# 4   Uruguay - France, 0 - 2                Pass   926.139298          2H
# 22  Uruguay - France, 0 - 2  Others on the ball   927.620581          2H
# 23  Uruguay - France, 0 - 2                Pass   930.959616          2H
# 15  Uruguay - France, 0 - 2                Duel   931.862696          2H
# 3   Uruguay - France, 0 - 2                Duel   931.899756          2H
# 24  Uruguay - France, 0 - 2                Duel   933.068363          2H
# 13  Uruguay - France, 0 - 2                Duel   933.365279          2H
# 25  Uruguay - France, 0 - 2                Pass   934.190860          2H
# 16  Uruguay - France, 0 - 2                Pass   935.060937          2H
# 19  Uruguay - France, 0 - 2  Others on the ball   935.207443          2H
# 17  Uruguay - France, 0 - 2                Pass   936.077399          2H
# 20  Uruguay - France, 0 - 2  Others on the ball   937.225753          2H
# 8   Uruguay - France, 0 - 2                Duel   938.453529          2H
# 21  Uruguay - France, 0 - 2                Duel   938.545362          2H
# 9   Uruguay - France, 0 - 2  Others on the ball   940.924987          2H
# 10  Uruguay - France, 0 - 2                Pass   943.411467          2H
# 5   Uruguay - France, 0 - 2                Pass   945.178696          2H
# 11  Uruguay - France, 0 - 2                Shot   947.251197          2H
#
#        Team             Player Position   Status
# 1    France       A. Griezmann       AM     DRAW
# 2   Uruguay          C. Stuani      NaN     DRAW
# 0    France          R. Varane       CB     DRAW
# 14  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 6    France          R. Varane       CB  LEADING
# 7    France          H. Lloris      GKP  LEADING
# 18  Uruguay    J. Gim\u00e9nez      NaN  LEADING
# 12   France          O. Giroud       CF  LEADING
# 4    France         C. Tolisso       CM  LEADING
# 22  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 23  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 15  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 3    France          B. Pavard       RB  LEADING
# 24  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 13   France          O. Giroud       CF  LEADING
# 25  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 16  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 19  Uruguay          M. Vecino      NaN  LEADING
# 17  Uruguay        L. Torreira      NaN  LEADING
# 20  Uruguay          M. Vecino      NaN  LEADING
# 8    France           P. Pogba       CM  LEADING
# 21  Uruguay          M. Vecino      NaN  LEADING
# 9    France           P. Pogba       CM  LEADING
# 10   France           P. Pogba       CM  LEADING
# 5    France         C. Tolisso       CM  LEADING
# 11   France       A. Griezmann       AM  LEADING

# %%
events_uruguay_france = events_uruguay[events_uruguay['Team'] == 'France']

# %% [markdown]
# Belgium - France

# %%
events_belgium = events_before_goal_by_minutes(data, 'Belgium', minutes=1)
events_belgium
# Out:
#                  SubEvent                                               Tags  \
# 2             Simple pass                                           Accurate
# 12            Simple pass                                           Accurate
# 3             Simple pass                                           Accurate
# 1             Simple pass                                           Accurate
# 0             Simple pass                                           Accurate
# 8             Simple pass                                           Accurate
# 4             Simple pass                                           Accurate
# 9             Simple pass                                           Accurate
# 13            Simple pass                                           Accurate
# 10  Ground attacking duel                    Free space right, Won, Accurate
# 15  Ground defending duel                Free space left, Lost, Not accurate
# 11                   Shot     Right foot, Blocked, Opportunity, Not accurate
# 16                  Touch                                       Interception
# 7                  Corner                             Assist, High, Accurate
# 14               Air duel                                 Lost, Not accurate
# 5                Air duel                                      Won, Accurate
# 6                    Shot  Goal, Head/body, Opportunity, Position: Goal c...
#
#                       Match               Event    EventSec MatchPeriod  \
# 2   France - Belgium, 1 - 0                Pass  278.729058          2H
# 12  France - Belgium, 1 - 0                Pass  279.349046          2H
# 3   France - Belgium, 1 - 0                Pass  281.916241          2H
# 1   France - Belgium, 1 - 0                Pass  284.663701          2H
# 0   France - Belgium, 1 - 0                Pass  288.558720          2H
# 8   France - Belgium, 1 - 0                Pass  293.119569          2H
# 4   France - Belgium, 1 - 0                Pass  296.252103          2H
# 9   France - Belgium, 1 - 0                Pass  297.398289          2H
# 13  France - Belgium, 1 - 0                Pass  300.399799          2H
# 10  France - Belgium, 1 - 0                Duel  302.210310          2H
# 15  France - Belgium, 1 - 0                Duel  302.393239          2H
# 11  France - Belgium, 1 - 0                Shot  302.735838          2H
# 16  France - Belgium, 1 - 0  Others on the ball  303.951718          2H
# 7   France - Belgium, 1 - 0           Free Kick  334.496557          2H
# 14  France - Belgium, 1 - 0                Duel  335.240263          2H
# 5   France - Belgium, 1 - 0                Duel  335.640221          2H
# 6   France - Belgium, 1 - 0                Shot  336.270432          2H
#
#        Team             Player Position Status
# 2    France          S. Umtiti       CB   DRAW
# 12   France         B. Matuidi       LM   DRAW
# 3    France          S. Umtiti       CB   DRAW
# 1    France          H. Lloris      GKP   DRAW
# 0    France          R. Varane       CB   DRAW
# 8    France      N. Kant\u00e9      CDM   DRAW
# 4    France          S. Umtiti       CB   DRAW
# 9    France  L. Hern\u00e1ndez       LB   DRAW
# 13   France         B. Matuidi       LM   DRAW
# 10   France          O. Giroud       CF   DRAW
# 15  Belgium         V. Kompany      NaN   DRAW
# 11   France          O. Giroud       CF   DRAW
# 16  Belgium         V. Kompany      NaN   DRAW
# 7    France       A. Griezmann       AM   DRAW
# 14  Belgium        M. Fellaini      NaN   DRAW
# 5    France          S. Umtiti       CB   DRAW
# 6    France          S. Umtiti       CB   DRAW

# %%
events_belgium_france = events_belgium[events_belgium['Team'] == 'France']

# %% [markdown]
# France - Croatia

# %%
events_croatia = events_before_goal_by_minutes(data, 'Croatia', minutes=1)
events_croatia
# Out:
#                  SubEvent                                               Tags  \
# 82  Ground defending duel                                 Lost, Not accurate
# 89  Ground attacking duel                                      Won, Accurate
# 83                   Foul                                        Yellow card
# 88        Free kick cross                                     High, Accurate
# 86              Head pass                                           Accurate
# ..                    ...                                                ...
# 66            Simple pass                             Interception, Accurate
# 65            Simple pass                                           Accurate
# 61  Ground attacking duel  Dangerous ball lost, Free space left, Lost, No...
# 73  Ground defending duel                    Free space right, Won, Accurate
# 74                   Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                       Match      Event     EventSec MatchPeriod     Team  \
# 82  France - Croatia, 4 - 2       Duel  1616.441157          1H   France
# 89  France - Croatia, 4 - 2       Duel  1616.441157          1H  Croatia
# 83  France - Croatia, 4 - 2       Foul  1618.274416          1H   France
# 88  France - Croatia, 4 - 2  Free Kick  1667.389939          1H  Croatia
# 86  France - Croatia, 4 - 2       Pass  1671.715305          1H  Croatia
# ..                      ...        ...          ...         ...      ...
# 66  France - Croatia, 4 - 2       Pass  1381.101172          2H   France
# 65  France - Croatia, 4 - 2       Pass  1385.191539          2H   France
# 61  France - Croatia, 4 - 2       Duel  1388.157139          2H   France
# 73  France - Croatia, 4 - 2       Duel  1388.157139          2H  Croatia
# 74  France - Croatia, 4 - 2       Shot  1389.182669          2H  Croatia
#
#                     Player Position   Status
# 82           N. Kant\u00e9      CDM  LEADING
# 89    I. Peri\u0161i\u0107      NaN  LEADING
# 83           N. Kant\u00e9      CDM  LEADING
# 88          L. Modri\u0107      NaN  LEADING
# 86  M. Mand\u017euki\u0107      NaN  LEADING
# ..                     ...      ...      ...
# 66       L. Hern\u00e1ndez       LB  LEADING
# 65               S. Umtiti       CB  LEADING
# 61               H. Lloris      GKP  LEADING
# 73  M. Mand\u017euki\u0107      NaN  LEADING
# 74  M. Mand\u017euki\u0107      NaN  LEADING
#
# [94 rows x 10 columns]

# %%
events_croatia_france = events_croatia[events_croatia['Team'] == 'France']

# %% [markdown]
# France - Australia

# %%
events_australia = events_before_goal_by_minutes(data, 'Australia', minutes=1)
events_australia
# Out:
#   SubEvent                                               Tags  \
# 1  Penalty  Goal, Left foot, Position: Goal center right, ...
# 0  Penalty  Goal, Right foot, Position: Goal low right, Ac...
#
#                        Match      Event    EventSec MatchPeriod       Team  \
# 1  France - Australia, 2 - 1  Free Kick  730.009243          2H     France
# 0  France - Australia, 2 - 1  Free Kick  976.718211          2H  Australia
#
#          Player Position   Status
# 1  A. Griezmann       AM     DRAW
# 0    M. Jedinak      NaN  LEADING

# %%
events_australia_france = events_australia[events_australia['Team'] == 'France']

# %% [markdown]
# France - Peru

# %%
events_peru = events_before_goal_by_minutes(data, 'Peru', minutes=1)
events_peru
# Out:
#                   SubEvent                                               Tags  \
# 5   Ground loose ball duel                                      Won, Accurate
# 25  Ground loose ball duel                                 Lost, Not accurate
# 6              Simple pass                                           Accurate
# 14             Simple pass                                           Accurate
# 11             Simple pass                                           Accurate
# 19  Ground loose ball duel                 Sliding tackle, Lost, Not accurate
# 0                High pass                        Key pass, Through, Accurate
# 9                     Shot  Right foot, Opportunity, Position: Goal center...
# 26                Reflexes                    Position: Goal center, Accurate
# 16             Simple pass                                           Accurate
# 7    Ground defending duel                         Anticipated, Won, Accurate
# 21   Ground attacking duel                   Anticipation, Lost, Not accurate
# 8              Simple pass                                           Accurate
# 3             Acceleration                                           Accurate
# 4              Simple pass                                           Accurate
# 12             Simple pass                                           Accurate
# 15  Ground loose ball duel                      Sliding tackle, Won, Accurate
# 17             Simple pass                                           Accurate
# 22             Simple pass                                           Accurate
# 20             Simple pass                                           Accurate
# 23                   Touch
# 1   Ground loose ball duel                                      Won, Accurate
# 24  Ground loose ball duel                 Sliding tackle, Lost, Not accurate
# 2               Smart pass                        Key pass, Through, Accurate
# 13                    Shot      Left foot, Blocked, Opportunity, Not accurate
# 18                   Touch                                       Interception
# 10                    Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                    Match               Event     EventSec MatchPeriod    Team  \
# 5   France - Peru, 1 - 0                Duel  1965.524366          1H  France
# 25  France - Peru, 1 - 0                Duel  1966.549858          1H    Peru
# 6   France - Peru, 1 - 0                Pass  1967.647707          1H  France
# 14  France - Peru, 1 - 0                Pass  1969.370714          1H  France
# 11  France - Peru, 1 - 0                Pass  1971.975232          1H  France
# 19  France - Peru, 1 - 0                Duel  1972.539213          1H    Peru
# 0   France - Peru, 1 - 0                Pass  1977.211491          1H  France
# 9   France - Peru, 1 - 0                Shot  1978.651572          1H  France
# 26  France - Peru, 1 - 0        Save attempt  1980.363205          1H    Peru
# 16  France - Peru, 1 - 0                Pass  2005.047435          1H    Peru
# 7   France - Peru, 1 - 0                Duel  2005.549289          1H  France
# 21  France - Peru, 1 - 0                Duel  2005.830183          1H    Peru
# 8   France - Peru, 1 - 0                Pass  2006.619300          1H  France
# 3   France - Peru, 1 - 0  Others on the ball  2008.080689          1H  France
# 4   France - Peru, 1 - 0                Pass  2010.527621          1H  France
# 12  France - Peru, 1 - 0                Pass  2011.249041          1H  France
# 15  France - Peru, 1 - 0                Duel  2012.546616          1H    Peru
# 17  France - Peru, 1 - 0                Pass  2013.813400          1H    Peru
# 22  France - Peru, 1 - 0                Pass  2017.342216          1H    Peru
# 20  France - Peru, 1 - 0                Pass  2018.321334          1H    Peru
# 23  France - Peru, 1 - 0  Others on the ball  2019.295633          1H    Peru
# 1   France - Peru, 1 - 0                Duel  2019.807640          1H  France
# 24  France - Peru, 1 - 0                Duel  2019.978058          1H    Peru
# 2   France - Peru, 1 - 0                Pass  2022.354070          1H  France
# 13  France - Peru, 1 - 0                Shot  2023.580214          1H  France
# 18  France - Peru, 1 - 0  Others on the ball  2024.690943          1H    Peru
# 10  France - Peru, 1 - 0                Shot  2025.334462          1H  France
#
#                Player Position Status
# 5       N. Kant\u00e9      CDM   DRAW
# 25     \u00c9. Flores      NaN   DRAW
# 6       N. Kant\u00e9      CDM   DRAW
# 14         B. Matuidi       LM   DRAW
# 11  L. Hern\u00e1ndez       LB   DRAW
# 19  L. Adv\u00edncula      NaN   DRAW
# 0            P. Pogba       CM   DRAW
# 9      K. Mbapp\u00e9       CF   DRAW
# 26         P. Gallese      NaN   DRAW
# 16  A. Rodr\u00edguez      NaN   DRAW
# 7       N. Kant\u00e9      CDM   DRAW
# 21        P. Guerrero      NaN   DRAW
# 8       N. Kant\u00e9      CDM   DRAW
# 3        A. Griezmann       AM   DRAW
# 4        A. Griezmann       AM   DRAW
# 12          O. Giroud       CF   DRAW
# 15      Y. Yot\u00fan      NaN   DRAW
# 17  A. Rodr\u00edguez      NaN   DRAW
# 22        P. Guerrero      NaN   DRAW
# 20  L. Adv\u00edncula      NaN   DRAW
# 23        P. Guerrero      NaN   DRAW
# 1            P. Pogba       CM   DRAW
# 24        P. Guerrero      NaN   DRAW
# 2            P. Pogba       CM   DRAW
# 13          O. Giroud       CF   DRAW
# 18  A. Rodr\u00edguez      NaN   DRAW
# 10     K. Mbapp\u00e9       CF   DRAW

# %%
events_peru_france = events_peru[events_peru['Team'] == 'France']

# %%
all_events_before_goals = pd.concat([events_argentina, events_uruguay, events_croatia, events_australia, events_belgium, events_peru], ignore_index=True)
all_events_before_goals
# Out:
#                    SubEvent  \
# 0                   Penalty
# 1               Simple pass
# 2     Ground attacking duel
# 3     Ground defending duel
# 4                    Corner
# ..                      ...
# 261  Ground loose ball duel
# 262              Smart pass
# 263                    Shot
# 264                   Touch
# 265                    Shot
#
#                                                   Tags  \
# 0    Goal, Left foot, Position: Goal low center, Ac...
# 1                                             Accurate
# 2                  Free space right, Neutral, Accurate
# 3                   Free space left, Neutral, Accurate
# 4                                       High, Accurate
# ..                                                 ...
# 261                 Sliding tackle, Lost, Not accurate
# 262                        Key pass, Through, Accurate
# 263      Left foot, Blocked, Opportunity, Not accurate
# 264                                       Interception
# 265  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 1    France - Argentina, 4 - 3                Pass  2385.262866          1H
# 2    France - Argentina, 4 - 3                Duel  2389.505394          1H
# 3    France - Argentina, 4 - 3                Duel  2391.157729          1H
# 4    France - Argentina, 4 - 3           Free Kick  2411.425619          1H
# ..                         ...                 ...          ...         ...
# 261       France - Peru, 1 - 0                Duel  2019.978058          1H
# 262       France - Peru, 1 - 0                Pass  2022.354070          1H
# 263       France - Peru, 1 - 0                Shot  2023.580214          1H
# 264       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 265       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#           Team             Player Position   Status
# 0       France       A. Griezmann       AM     DRAW
# 1    Argentina         G. Mercado      NaN  LEADING
# 2    Argentina           L. Messi      NaN  LEADING
# 3       France      N. Kant\u00e9      CDM  LEADING
# 4    Argentina           L. Messi      NaN  LEADING
# ..         ...                ...      ...      ...
# 261       Peru        P. Guerrero      NaN     DRAW
# 262     France           P. Pogba       CM     DRAW
# 263     France          O. Giroud       CF     DRAW
# 264       Peru  A. Rodr\u00edguez      NaN     DRAW
# 265     France     K. Mbapp\u00e9       CF     DRAW
#
# [266 rows x 10 columns]

# %%
filtered_events = all_events_before_goals[
    ~(
        (all_events_before_goals['Event'] == 'Duel') & 
        (all_events_before_goals['Tags'].str.contains("Lost"))
    )
]

filtered_events
# Out:
#                    SubEvent  \
# 0                   Penalty
# 1               Simple pass
# 2     Ground attacking duel
# 3     Ground defending duel
# 4                    Corner
# ..                      ...
# 260  Ground loose ball duel
# 262              Smart pass
# 263                    Shot
# 264                   Touch
# 265                    Shot
#
#                                                   Tags  \
# 0    Goal, Left foot, Position: Goal low center, Ac...
# 1                                             Accurate
# 2                  Free space right, Neutral, Accurate
# 3                   Free space left, Neutral, Accurate
# 4                                       High, Accurate
# ..                                                 ...
# 260                                      Won, Accurate
# 262                        Key pass, Through, Accurate
# 263      Left foot, Blocked, Opportunity, Not accurate
# 264                                       Interception
# 265  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 1    France - Argentina, 4 - 3                Pass  2385.262866          1H
# 2    France - Argentina, 4 - 3                Duel  2389.505394          1H
# 3    France - Argentina, 4 - 3                Duel  2391.157729          1H
# 4    France - Argentina, 4 - 3           Free Kick  2411.425619          1H
# ..                         ...                 ...          ...         ...
# 260       France - Peru, 1 - 0                Duel  2019.807640          1H
# 262       France - Peru, 1 - 0                Pass  2022.354070          1H
# 263       France - Peru, 1 - 0                Shot  2023.580214          1H
# 264       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 265       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#           Team             Player Position   Status
# 0       France       A. Griezmann       AM     DRAW
# 1    Argentina         G. Mercado      NaN  LEADING
# 2    Argentina           L. Messi      NaN  LEADING
# 3       France      N. Kant\u00e9      CDM  LEADING
# 4    Argentina           L. Messi      NaN  LEADING
# ..         ...                ...      ...      ...
# 260     France           P. Pogba       CM     DRAW
# 262     France           P. Pogba       CM     DRAW
# 263     France          O. Giroud       CF     DRAW
# 264       Peru  A. Rodr\u00edguez      NaN     DRAW
# 265     France     K. Mbapp\u00e9       CF     DRAW
#
# [232 rows x 10 columns]

# %%
all_events_before_goals['Match'].unique()
# Out:
# array(['France - Argentina, 4 - 3', 'Uruguay - France, 0 - 2',
#        'France - Croatia, 4 - 2', 'France - Australia, 2 - 1',
#        'France - Belgium, 1 - 0', 'France - Peru, 1 - 0'], dtype=object)

# %% [markdown]
# ##We have shot, freekick shot, cross , freekick cross, corner in subevent which are more exciting for now.

# %%
def sort_by_match(data):
    return data.sort_values(by=['Match','MatchPeriod', 'EventSec'])

all_events_before_goals_sorted = sort_by_match(all_events_before_goals)
filtered_events_sorted = sort_by_match(filtered_events)

# %% [markdown]
# We have finished our data preparation. Time to create an structured XES file

# %%
from datetime import datetime, timedelta

def create_non_filter_xes_file(data, filename="output.xes", checkOn :str = "org:resource"):

    def has_allowed_subevent(trace):
        return True

    def safe_str(value):
        """Safely convert value to string, handling NaN"""
        if pd.isna(value):
            return ""
        return str(value)

    base_datetime = datetime(2020, 1, 1) # Arbitrary date for the timestamp

    # Open file to write
    with open(filename, 'w') as f:
        # Write XML declaration and log opening tag
        f.write('<?xml version="1.0" encoding="UTF-8" ?>\n')
        f.write('<log xes.version="1.0" xes.features="nested-attributes" openxes.version="1.0RC7" xmlns="http://www.xes-standard.org/">\n')
        f.write(f'<classifier name="Activity_Resource" keys="{checkOn}"/>\n')
        f.write('<classifier name="Default" keys="concept:name"/>\n')
        
        # Initialize variables for tracking traces
        current_trace = []
        in_possession = False
        last_opponent_action = None  # To keep track of the last action by the opponent
        
        # Iterate over each row in the data
        for idx, row in data.iterrows():
            # Check if the team is "France"
            if row['Team'] == 'France':
                # Start a new trace if we're not in possession
                if not in_possession:
                    # If there was a previous trace, write it to the file
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            start_reason = last_opponent_action  # Set start reason to last opponent action
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = True
                
                # Add the current event to the trace
                current_trace.append({
                    'Player': row['Player'],
                    'Position': row['Position'],
                    'Event': row['Event'],
                    'EventSec': row['EventSec'],
                    'SubEvent': row['SubEvent'],
                    'MatchPeriod': row['MatchPeriod'],
                    'Tags': row['Tags'],
                    "Match": row['Match'],
                    "Status": row['Status']
                })
                
            else:
                # If team is not France, complete the current trace
                if in_possession:
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = False
                
                # Keep track of the last action of the opponent
                last_opponent_action = row['Event']  # Update the last opponent action
        
        # Close the remaining trace if still in possession
        if current_trace:
            # Only write trace if it contains an allowed subevent
            if has_allowed_subevent(current_trace):
                end_reason = current_trace[-1]['Event']
                start_reason = last_opponent_action  # Use last opponent action as start reason
                
                f.write('  <trace>\n')
                f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                
                # Write each event in the trace
                for event in current_trace:
                    event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                    event_timestamp = event_datetime.isoformat() 
                    f.write('    <event>\n')
                    f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                    f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                    f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                    f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                    f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                    f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                    f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                    f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                    f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                    f.write('    </event>\n')
                
                f.write('  </trace>\n')
        
        # Close log
        f.write('</log>\n')

# %%
from datetime import datetime, timedelta

def create_attack_xes_data(data, filename="output.xes", checkOn :str = "org:resource"):
    # Define the allowed subevents
    ALLOWED_SUBEVENTS = {
        "Shot",
        "Free kick shot",
        "Cross",
        "Free kick cross",
        "Corner"
    }

    def has_allowed_subevent(trace):
        """Check if any event in the trace has an allowed subevent"""
        for event in trace:
            subevent = event['SubEvent']
            # Check if subevent is NaN or not a string
            if pd.isna(subevent) or not isinstance(subevent, str):
                continue
                
            # Split subevents by space and check each one
            subevents = subevent.split(' ')
            if any(subevent in ALLOWED_SUBEVENTS for subevent in subevents):
                return True
        return False

    def safe_str(value):
        """Safely convert value to string, handling NaN"""
        if pd.isna(value):
            return ""
        return str(value)

    base_datetime = datetime(2020, 1, 1) # Arbitrary date for the timestamp

    # Open file to write
    with open(filename, 'w') as f:
        # Write XML declaration and log opening tag
        f.write('<?xml version="1.0" encoding="UTF-8" ?>\n')
        f.write('<log xes.version="1.0" xes.features="nested-attributes" openxes.version="1.0RC7" xmlns="http://www.xes-standard.org/">\n')
        f.write(f'<classifier name="Activity_Resource" keys="{checkOn}"/>\n')
        f.write('<classifier name="Default" keys="concept:name"/>\n')
        
        # Initialize variables for tracking traces
        current_trace = []
        in_possession = False
        last_opponent_action = None  # To keep track of the last action by the opponent
        
        # Iterate over each row in the data
        for idx, row in data.iterrows():
            # Check if the team is "France"
            if row['Team'] == 'France':
                # Start a new trace if we're not in possession
                if not in_possession:
                    # If there was a previous trace, write it to the file
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            start_reason = last_opponent_action  # Set start reason to last opponent action
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = True
                
                # Add the current event to the trace
                current_trace.append({
                    'Player': row['Player'],
                    'Position': row['Position'],
                    'Event': row['Event'],
                    'EventSec': row['EventSec'],
                    'SubEvent': row['SubEvent'],
                    'MatchPeriod': row['MatchPeriod'],
                    'Tags': row['Tags'],
                    "Match": row['Match'],
                    "Status": row['Status']
                })
                
            else:
                # If team is not France, complete the current trace
                if in_possession:
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = False
                
                # Keep track of the last action of the opponent
                last_opponent_action = row['Event']  # Update the last opponent action
        
        # Close the remaining trace if still in possession
        if current_trace:
            # Only write trace if it contains an allowed subevent
            if has_allowed_subevent(current_trace):
                end_reason = current_trace[-1]['Event']
                start_reason = last_opponent_action  # Use last opponent action as start reason
                
                f.write('  <trace>\n')
                f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                
                # Write each event in the trace
                for event in current_trace:
                    event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                    event_timestamp = event_datetime.isoformat() 
                    f.write('    <event>\n')
                    f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                    f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                    f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                    f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                    f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                    f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                    f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                    f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                    f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                    f.write('    </event>\n')
                
                f.write('  </trace>\n')
        
        # Close log
        f.write('</log>\n')

# %%
# vs_denmark = data[data['Match'].str.contains('Denmark - France', na=False)]
# create_attack_xes_data(sort_by_match(vs_denmark), filename="vs_denmark_attack.xes")
# create_non_filter_xes_file(sort_by_match(vs_denmark), filename="vs_denmark_all.xes")

create_non_filter_xes_file(all_events_before_goals_sorted, filename="all.xes")
create_attack_xes_data(all_events_before_goals_sorted, filename="all_attack.xes")

create_non_filter_xes_file(filtered_events_sorted, filename="filtered_all.xes")
create_attack_xes_data(filtered_events_sorted, filename="filtered_all_attack.xes")

create_non_filter_xes_file(sort_by_match(events_belgium), filename="belgium_non_filtered.xes")
# create_attack_xes_data(sort_by_match(events_belgium), filename="belgium_attack.xes")

create_non_filter_xes_file(sort_by_match(events_argentina), filename="argentina_non_filtered.xes")
create_non_filter_xes_file(sort_by_match(events_uruguay), filename="uruguay_non_filtered.xes")
create_non_filter_xes_file(sort_by_match(events_croatia), filename="croatia_non_filtered.xes")
create_non_filter_xes_file(sort_by_match(events_australia), filename="australia_non_filtered.xes")
create_non_filter_xes_file(sort_by_match(events_peru), filename="peru_non_filtered.xes")
