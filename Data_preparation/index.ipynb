# %%
import pandas as pd
import ast

# %%
events_world_cup =pd.read_csv('../events_World_Cup.csv')
teams = pd.read_csv('../teams.csv')
tags2name = pd.read_csv('../tags2name.csv')
playerrank = pd.read_csv('../playerank.csv')
players = pd.read_csv('../players.csv')
matches_world_cup = pd.read_csv('../matches_World_Cup.csv')

# %% [markdown]
# Lets filter the unrequired columns

# %%
events_world_cup = events_world_cup[['subEventName', 'tags', 'playerId', 'matchId', 'eventName', 'teamId', 'eventSec', 'matchPeriod']]
players = players[['wyId', 'shortName']]
tags2name = tags2name[['Tag', 'Description']]
teams = teams[['wyId', 'officialName', 'type']]
playerrank = playerrank[['playerId', 'roleCluster']]

# %% [markdown]
# Start filtering the data

# %%
# Only national teams
teams = teams[teams['type'] == 'national']

# Only matches where France has played.
matches_world_cup = matches_world_cup[matches_world_cup['label'].str.contains("France")]

# Only events from the matches where France has played.
events_world_cup = events_world_cup[events_world_cup['matchId'].isin(matches_world_cup['wyId'])]

events_world_cup
# Out:
#        subEventName            tags  playerId  matchId           eventName  \
# 18813   Simple pass  [{'id': 1801}]    238055  2057966                Pass
# 18814     High pass  [{'id': 1802}]     61395  2057966                Pass
# 18815      Throw in  [{'id': 1801}]    340646  2057966           Free Kick
# 18816   Simple pass  [{'id': 1801}]    209091  2057966                Pass
# 18817        Launch  [{'id': 1802}]    340646  2057966                Pass
# ...             ...             ...       ...      ...                 ...
# 101751    High pass  [{'id': 1802}]     69396  2058017                Pass
# 101752    Clearance  [{'id': 1802}]      3309  2058017  Others on the ball
# 101753     Throw in  [{'id': 1801}]     69968  2058017           Free Kick
# 101754  Simple pass  [{'id': 1801}]      3476  2058017                Pass
# 101755        Touch              []     14812  2058017  Others on the ball
#
#         teamId     eventSec matchPeriod
# 18813     8493     1.435354          1H
# 18814     8493     3.978396          1H
# 18815     4418    15.608867          1H
# 18816     4418    16.385084          1H
# 18817     4418    17.214485          1H
# ...        ...          ...         ...
# 101751    9598  2964.715715          2H
# 101752    4418  2967.926784          2H
# 101753    9598  2972.985039          2H
# 101754    9598  2978.301867          2H
# 101755    9598  2979.084611          2H
#
# [10843 rows x 8 columns]

# %%
# Merge match name
data = pd.merge(events_world_cup, teams, left_on='teamId', right_on='wyId')
data
# Out:
#       subEventName                         tags  playerId  matchId  \
# 0      Simple pass               [{'id': 1801}]    238055  2057966
# 1        High pass               [{'id': 1802}]     61395  2057966
# 2        Head pass               [{'id': 1802}]     61425  2057966
# 3        High pass               [{'id': 1801}]     62389  2057966
# 4         Air duel  [{'id': 701}, {'id': 1802}]     16151  2057966
# ...            ...                          ...       ...      ...
# 10838        Touch                           []     69396  2058017
# 10839    High pass               [{'id': 1802}]     69396  2058017
# 10840     Throw in               [{'id': 1801}]     69968  2058017
# 10841  Simple pass               [{'id': 1801}]      3476  2058017
# 10842        Touch                           []     14812  2058017
#
#                 eventName  teamId     eventSec matchPeriod  wyId officialName  \
# 0                    Pass    8493     1.435354          1H  8493    Australia
# 1                    Pass    8493     3.978396          1H  8493    Australia
# 2                    Pass    8493    19.920463          1H  8493    Australia
# 3                    Pass    8493    26.371362          1H  8493    Australia
# 4                    Duel    8493    27.942092          1H  8493    Australia
# ...                   ...     ...          ...         ...   ...          ...
# 10838  Others on the ball    9598  2960.803153          2H  9598      Croatia
# 10839                Pass    9598  2964.715715          2H  9598      Croatia
# 10840           Free Kick    9598  2972.985039          2H  9598      Croatia
# 10841                Pass    9598  2978.301867          2H  9598      Croatia
# 10842  Others on the ball    9598  2979.084611          2H  9598      Croatia
#
#            type
# 0      national
# 1      national
# 2      national
# 3      national
# 4      national
# ...         ...
# 10838  national
# 10839  national
# 10840  national
# 10841  national
# 10842  national
#
# [10843 rows x 11 columns]

# %%
# Merge player name
data = pd.merge(data, players, left_on='playerId', right_on='wyId')
data
# Out:
#                  subEventName                                      tags  \
# 0                 Simple pass                            [{'id': 1801}]
# 1                 Simple pass                            [{'id': 1801}]
# 2      Ground loose ball duel               [{'id': 701}, {'id': 1802}]
# 3                   Head pass                            [{'id': 1801}]
# 4                    Air duel               [{'id': 701}, {'id': 1802}]
# ...                       ...                                       ...
# 10838             Simple pass                            [{'id': 1801}]
# 10839   Ground attacking duel  [{'id': 502}, {'id': 703}, {'id': 1801}]
# 10840             Simple pass                            [{'id': 1802}]
# 10841             Simple pass                            [{'id': 1801}]
# 10842   Ground defending duel               [{'id': 703}, {'id': 1801}]
#
#        playerId  matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0        238055  2057966      Pass    8493     1.435354          1H    8493
# 1        238055  2057966      Pass    8493   318.452504          1H    8493
# 2        238055  2057966      Duel    8493   622.800480          1H    8493
# 3        238055  2057966      Pass    8493  1089.881235          1H    8493
# 4        238055  2057966      Duel    8493  1310.158067          1H    8493
# ...         ...      ...       ...     ...          ...         ...     ...
# 10838     69411  2058017      Pass    9598  2888.451480          2H    9598
# 10839    135810  2058017      Duel    9598  2398.932619          2H    9598
# 10840    135810  2058017      Pass    9598  2400.002448          2H    9598
# 10841    135810  2058017      Pass    9598  2567.478676          2H    9598
# 10842    135810  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
# Merge tags

def map_tags_to_desc(tag_list):
    descriptions = []
    for tag in tag_list:
        tag_id = tag['id']
        description = tags2name.loc[tags2name['Tag'] == tag_id, 'Description'].values
        if len(description) > 0:
            descriptions.append(description[0])
    return descriptions

data['tags'] = data['tags'].apply(lambda x: map_tags_to_desc(ast.literal_eval(x)))
data
# Out:
#                  subEventName                              tags  playerId  \
# 0                 Simple pass                        [Accurate]    238055
# 1                 Simple pass                        [Accurate]    238055
# 2      Ground loose ball duel              [Lost, Not accurate]    238055
# 3                   Head pass                        [Accurate]    238055
# 4                    Air duel              [Lost, Not accurate]    238055
# ...                       ...                               ...       ...
# 10838             Simple pass                        [Accurate]     69411
# 10839   Ground attacking duel  [Free space left, Won, Accurate]    135810
# 10840             Simple pass                    [Not accurate]    135810
# 10841             Simple pass                        [Accurate]    135810
# 10842   Ground defending duel                   [Won, Accurate]    135810
#
#        matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0      2057966      Pass    8493     1.435354          1H    8493
# 1      2057966      Pass    8493   318.452504          1H    8493
# 2      2057966      Duel    8493   622.800480          1H    8493
# 3      2057966      Pass    8493  1089.881235          1H    8493
# 4      2057966      Duel    8493  1310.158067          1H    8493
# ...        ...       ...     ...          ...         ...     ...
# 10838  2058017      Pass    9598  2888.451480          2H    9598
# 10839  2058017      Duel    9598  2398.932619          2H    9598
# 10840  2058017      Pass    9598  2400.002448          2H    9598
# 10841  2058017      Pass    9598  2567.478676          2H    9598
# 10842  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
data = data.drop(columns=['playerId', 'teamId', 'type', 'wyId_y', 'wyId_x'])

# Replace matchId with match label
data = data.merge(matches_world_cup[['wyId', 'label']], left_on='matchId', right_on='wyId', how='left')

data['matchId'] = data['label']
data = data.drop(columns=['label', 'wyId'])

data = data.rename(columns=
                   {'officialName': 'Team',
                    'shortName': 'Player',
                    'matchId' : 'Match',
                    'eventName': 'Event',
                    'tags': 'Tags', 
                    'matchPeriod': 'MatchPeriod',
                    'eventSec': 'EventSec',
                    'subEventName': 'SubEvent'}
                    )
data
# Out:
#                      SubEvent                              Tags  \
# 0                 Simple pass                        [Accurate]
# 1                 Simple pass                        [Accurate]
# 2      Ground loose ball duel              [Lost, Not accurate]
# 3                   Head pass                        [Accurate]
# 4                    Air duel              [Lost, Not accurate]
# ...                       ...                               ...
# 10838             Simple pass                        [Accurate]
# 10839   Ground attacking duel  [Free space left, Won, Accurate]
# 10840             Simple pass                    [Not accurate]
# 10841             Simple pass                        [Accurate]
# 10842   Ground defending duel                   [Won, Accurate]
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
data['Tags'] = data['Tags'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
data
# Out:
#                      SubEvent                            Tags  \
# 0                 Simple pass                        Accurate
# 1                 Simple pass                        Accurate
# 2      Ground loose ball duel              Lost, Not accurate
# 3                   Head pass                        Accurate
# 4                    Air duel              Lost, Not accurate
# ...                       ...                             ...
# 10838             Simple pass                        Accurate
# 10839   Ground attacking duel  Free space left, Won, Accurate
# 10840             Simple pass                    Not accurate
# 10841             Simple pass                        Accurate
# 10842   Ground defending duel                   Won, Accurate
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
grouped  = data.groupby('Match').size().reset_index(name='count')

# Data per match
grouped
# Out:
#                        Match  count
# 0    Denmark - France, 0 - 0   1581
# 1  France - Argentina, 4 - 3   1426
# 2  France - Australia, 2 - 1   1514
# 3    France - Belgium, 1 - 0   1588
# 4    France - Croatia, 4 - 2   1459
# 5       France - Peru, 1 - 0   1668
# 6    Uruguay - France, 0 - 2   1607

# %%
# All relevant french players
french_players = data[data['Team'] == 'France']['Player'].unique().tolist()
french_players
# Out:
# ['B. Pavard',
#  'C. Tolisso',
#  'R. Varane',
#  'H. Lloris',
#  'P. Pogba',
#  'S. Umtiti',
#  'A. Griezmann',
#  'N. Kant\\u00e9',
#  'K. Mbapp\\u00e9',
#  'L. Hern\\u00e1ndez',
#  'O. Demb\\u00e9l\\u00e9',
#  'N. Fekir',
#  'O. Giroud',
#  'B. Matuidi',
#  "S. N'Zonzi",
#  'D. Sidib\\u00e9',
#  'P. Kimpembe',
#  'T. Lemar',
#  'S. Mandanda',
#  'B. Mendy',
#  'F. Thauvin']

# %%
# Manually map the players to their respective postions
player_position_mapping = {
    'B. Pavard': 'RB',
    'C. Tolisso': 'CM',
    'R. Varane': 'CB',
    'H. Lloris': 'GKP',
    'P. Pogba': 'CM',
    'S. Umtiti': 'CB',
    'A. Griezmann': 'AM',
    'N. Kant\\u00e9': 'CDM',
    'K. Mbapp\\u00e9': 'CF',
    'L. Hern\\u00e1ndez': 'LB',
    'O. Demb\\u00e9l\\u00e9': 'RW',
    'N. Fekir': 'AM',
    'O. Giroud': 'CF',
    'B. Matuidi': 'LM',
    "S. N'Zonzi": 'CM',
    'D. Sidibé': 'RB',
    'P. Kimpembe': 'CB',
    'T. Lemar': 'LW',
    'S. Mandanda': 'GKP',
    'B. Mendy': 'LB',
    'F. Thauvin': 'RW',
    'D. Sidib\\u00e9': 'RB',
}

# Map the Position based on Player names
data['Position'] = data['Player'].map(player_position_mapping)

data[data['Team'] == 'France']
# Out:
#          SubEvent                              Tags  \
# 700      Throw in                          Accurate
# 701        Launch                      Not accurate
# 702   Simple pass                          Accurate
# 703   Simple pass                          Accurate
# 704   Simple pass                          Accurate
# ...           ...                               ...
# 6020  Simple pass                          Accurate
# 6021        Cross  Left foot, Blocked, Not accurate
# 6022     Throw in                          Accurate
# 6023  Simple pass                          Accurate
# 6024     Air duel                     Won, Accurate
#
#                           Match      Event     EventSec MatchPeriod    Team  \
# 700   France - Australia, 2 - 1  Free Kick    15.608867          1H  France
# 701   France - Australia, 2 - 1       Pass    17.214485          1H  France
# 702   France - Australia, 2 - 1       Pass    32.884277          1H  France
# 703   France - Australia, 2 - 1       Pass    54.866585          1H  France
# 704   France - Australia, 2 - 1       Pass    75.441589          1H  France
# ...                         ...        ...          ...         ...     ...
# 6020    Denmark - France, 0 - 0       Pass  2848.941221          2H  France
# 6021    Denmark - France, 0 - 0       Pass  2853.514985          2H  France
# 6022    Denmark - France, 0 - 0  Free Kick  2859.488457          2H  France
# 6023  France - Argentina, 4 - 3       Pass  2613.230156          2H  France
# 6024  France - Argentina, 4 - 3       Duel  2622.866067          2H  France
#
#           Player Position
# 700    B. Pavard       RB
# 701    B. Pavard       RB
# 702    B. Pavard       RB
# 703    B. Pavard       RB
# 704    B. Pavard       RB
# ...          ...      ...
# 6020    B. Mendy       LB
# 6021    B. Mendy       LB
# 6022    B. Mendy       LB
# 6023  F. Thauvin       RW
# 6024  F. Thauvin       RW
#
# [5325 rows x 9 columns]

# %%
data['SubEvent'] = data['SubEvent'].fillna('')

# %%
data["Status"] = "DRAW"

# France vs Australia

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

# Second goal conceded by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (17*60))
)
data.loc[mask, 'Status'] = 'DRAW'

mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (36*60))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Denmark is already prepopulated with draw

# France v Peru

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Peru', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (35*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Argentina

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (14*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (42*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (4*60 ))
)
data.loc[mask, 'Status'] = 'LOSING'

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'


#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (20*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# Uruguay vs France

#Scored
mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (40*60 ))
)

mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '2H'))
data.loc[mask, 'Status'] = 'LEADING'
# Belgium vs France

#Scored
mask = (
    data['Match'].str.contains('France - Belgium', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (7*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France - Croatia

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (20*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceeded
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (29*60))
)
data.loc[mask, 'Status'] = 'DRAW'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (39*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '2H') 
)
data.loc[mask, 'Status'] = 'LEADING'

# %% [markdown]
# ### Events before goals by given minute

# %%
def events_before_goal_by_minutes(data, opponent_team, minutes=1):  
    # Determine the times of all goals by France
    goal_times = data[
        data['Match'].str.contains(opponent_team, na=False) &
        (data['Tags'].str.contains('Goal,', na=False)) & 
        (data['Tags'].str.contains('Accurate', na=False) &
        (data['Team'] == 'France'))
    ][['EventSec', 'MatchPeriod']]
    
    if not goal_times.empty:
        events_before_goals = []
        
        for _, goal in goal_times.iterrows():
            goal_time = goal['EventSec']
            goal_period = goal['MatchPeriod']
            
            # Filter the events for the specified number of minutes before the goal (including the goal)
            events_before_goal = data[
                data['Match'].str.contains(opponent_team, na=False) &
                (data['MatchPeriod'] == goal_period) &
                (data['EventSec'] >= max(0, goal_time - minutes * 60)) & 
                (data['EventSec'] <= goal_time)
            ]
            
            events_before_goals.append(events_before_goal)
        
        # Concatenate all the events before each goal
        events_before_goal_df = pd.concat(events_before_goals, ignore_index=True)
        
        return events_before_goal_df.sort_values(by=['MatchPeriod', 'EventSec'])
    
    else:
        # Return an empty DataFrame if no goals are found
        return pd.DataFrame(columns=data.columns)

# %% [markdown]
# France - Denmark

# %%
events_denmark = events_before_goal_by_minutes(data, 'Denmark', minutes=2)
events_denmark
# Out:
# Empty DataFrame
# Columns: [SubEvent, Tags, Match, Event, EventSec, MatchPeriod, Team, Player, Position, Status]
# Index: []

# %% [markdown]
# France - Argentina

# %%
events_argentina = events_before_goal_by_minutes(data, 'Argentina', minutes=2)
events_argentina[events_argentina['Team'] == 'France']
# Out:
#                   SubEvent                                               Tags  \
# 37                 Penalty  Goal, Left foot, Position: Goal low center, Ac...
# 3              Simple pass                                           Accurate
# 22             Simple pass                                       Not accurate
# 10   Ground defending duel          Take on right, Anticipated, Won, Accurate
# 0              Simple pass                                           Accurate
# 4              Simple pass                                           Accurate
# 11                   Touch
# 12             Simple pass                                           Accurate
# 26             Simple pass                                       Not accurate
# 15  Ground loose ball duel                                  Neutral, Accurate
# 16  Ground loose ball duel                                  Neutral, Accurate
# 24                Air duel                                 Lost, Not accurate
# 7                Hand pass                                           Accurate
# 5              Simple pass                                           Accurate
# 23             Simple pass                                           Accurate
# 17             Simple pass                                           Accurate
# 1              Simple pass                                           Accurate
# 8                   Launch                                           Accurate
# 27  Ground loose ball duel                                      Won, Accurate
# 18             Simple pass                                           Accurate
# 13             Simple pass                                           Accurate
# 19             Simple pass                                           Accurate
# 14             Simple pass                                           Accurate
# 9              Simple pass                                           Accurate
# 6              Simple pass                                           Accurate
# 20                   Touch
# 21             Simple pass                                           Accurate
# 28              Smart pass                                  Through, Accurate
# 25                   Cross                          Left foot, High, Accurate
# 2                     Shot  Goal, Right foot, Opportunity, Position: Goal ...
# 45   Ground attacking duel                                      Won, Accurate
# 46               Free Kick                                           Accurate
# 49             Simple pass                                           Accurate
# 39                   Touch
# 40             Simple pass                                           Accurate
# 43             Simple pass                                           Accurate
# 41             Simple pass                                           Accurate
# 38             Simple pass                                           Accurate
# 42             Simple pass                                           Accurate
# 47                   Touch
# 48             Simple pass                                           Accurate
# 44             Simple pass                                           Accurate
# 52                   Cross                                Left foot, Accurate
# 53                    Shot      Left foot, Blocked, Opportunity, Not accurate
# 50   Ground attacking duel                        Take on left, Won, Accurate
# 51                    Shot  Goal, Left foot, Opportunity, Position: Goal l...
# 69               Clearance                         Interception, Not accurate
# 72               Clearance                                       Not accurate
# 70               Goal kick
# 73             Simple pass                                           Accurate
# 71             Simple pass                                           Accurate
# 75             Simple pass                                           Accurate
# 74             Simple pass                                           Accurate
# 78             Simple pass                                           Accurate
# 77             Simple pass                                   Assist, Accurate
# 76                    Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                         Match               Event     EventSec MatchPeriod  \
# 37  France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 3   France - Argentina, 4 - 3                Pass   589.283334          2H
# 22  France - Argentina, 4 - 3                Pass   593.816026          2H
# 10  France - Argentina, 4 - 3                Duel   594.475207          2H
# 0   France - Argentina, 4 - 3                Pass   597.481241          2H
# 4   France - Argentina, 4 - 3                Pass   600.873199          2H
# 11  France - Argentina, 4 - 3  Others on the ball   602.492381          2H
# 12  France - Argentina, 4 - 3                Pass   607.552599          2H
# 26  France - Argentina, 4 - 3                Pass   608.396092          2H
# 15  France - Argentina, 4 - 3                Duel   611.503109          2H
# 16  France - Argentina, 4 - 3                Duel   612.773855          2H
# 24  France - Argentina, 4 - 3                Duel   650.822751          2H
# 7   France - Argentina, 4 - 3                Pass   655.959008          2H
# 5   France - Argentina, 4 - 3                Pass   660.094663          2H
# 23  France - Argentina, 4 - 3                Pass   661.281821          2H
# 17  France - Argentina, 4 - 3                Pass   663.789611          2H
# 1   France - Argentina, 4 - 3                Pass   665.437266          2H
# 8   France - Argentina, 4 - 3                Pass   672.381157          2H
# 27  France - Argentina, 4 - 3                Duel   674.966694          2H
# 18  France - Argentina, 4 - 3                Pass   679.933245          2H
# 13  France - Argentina, 4 - 3                Pass   682.189040          2H
# 19  France - Argentina, 4 - 3                Pass   685.259225          2H
# 14  France - Argentina, 4 - 3                Pass   687.631849          2H
# 9   France - Argentina, 4 - 3                Pass   690.806781          2H
# 6   France - Argentina, 4 - 3                Pass   694.837939          2H
# 20  France - Argentina, 4 - 3  Others on the ball   697.448353          2H
# 21  France - Argentina, 4 - 3                Pass   700.549707          2H
# 28  France - Argentina, 4 - 3                Pass   702.349985          2H
# 25  France - Argentina, 4 - 3                Pass   705.627015          2H
# 2   France - Argentina, 4 - 3                Shot   708.161917          2H
# 45  France - Argentina, 4 - 3                Duel  1024.359294          2H
# 46  France - Argentina, 4 - 3           Free Kick  1049.105770          2H
# 49  France - Argentina, 4 - 3                Pass  1053.778440          2H
# 39  France - Argentina, 4 - 3  Others on the ball  1055.986914          2H
# 40  France - Argentina, 4 - 3                Pass  1059.374506          2H
# 43  France - Argentina, 4 - 3                Pass  1062.163056          2H
# 41  France - Argentina, 4 - 3                Pass  1065.000096          2H
# 38  France - Argentina, 4 - 3                Pass  1067.494307          2H
# 42  France - Argentina, 4 - 3                Pass  1070.782170          2H
# 47  France - Argentina, 4 - 3  Others on the ball  1072.821418          2H
# 48  France - Argentina, 4 - 3                Pass  1078.386281          2H
# 44  France - Argentina, 4 - 3                Pass  1080.811984          2H
# 52  France - Argentina, 4 - 3                Pass  1084.518196          2H
# 53  France - Argentina, 4 - 3                Shot  1085.701979          2H
# 50  France - Argentina, 4 - 3                Duel  1087.016026          2H
# 51  France - Argentina, 4 - 3                Shot  1088.431408          2H
# 69  France - Argentina, 4 - 3  Others on the ball  1259.420298          2H
# 72  France - Argentina, 4 - 3  Others on the ball  1284.631429          2H
# 70  France - Argentina, 4 - 3           Free Kick  1349.582519          2H
# 73  France - Argentina, 4 - 3                Pass  1355.363951          2H
# 71  France - Argentina, 4 - 3                Pass  1357.956948          2H
# 75  France - Argentina, 4 - 3                Pass  1362.232707          2H
# 74  France - Argentina, 4 - 3                Pass  1363.313748          2H
# 78  France - Argentina, 4 - 3                Pass  1366.156036          2H
# 77  France - Argentina, 4 - 3                Pass  1367.556927          2H
# 76  France - Argentina, 4 - 3                Shot  1369.345368          2H
#
#       Team             Player Position   Status
# 37  France       A. Griezmann       AM     DRAW
# 3   France          R. Varane       CB   LOSING
# 22  France     K. Mbapp\u00e9       CF   LOSING
# 10  France           P. Pogba       CM   LOSING
# 0   France          B. Pavard       RB   LOSING
# 4   France          R. Varane       CB   LOSING
# 11  France          S. Umtiti       CB   LOSING
# 12  France          S. Umtiti       CB   LOSING
# 26  France          O. Giroud       CF   LOSING
# 15  France       A. Griezmann       AM   LOSING
# 16  France       A. Griezmann       AM   LOSING
# 24  France  L. Hern\u00e1ndez       LB   LOSING
# 7   France          H. Lloris      GKP   LOSING
# 5   France          R. Varane       CB   LOSING
# 23  France     K. Mbapp\u00e9       CF   LOSING
# 17  France      N. Kant\u00e9      CDM   LOSING
# 1   France          B. Pavard       RB   LOSING
# 8   France          H. Lloris      GKP   LOSING
# 27  France          O. Giroud       CF   LOSING
# 18  France      N. Kant\u00e9      CDM   LOSING
# 13  France          S. Umtiti       CB   LOSING
# 19  France      N. Kant\u00e9      CDM   LOSING
# 14  France          S. Umtiti       CB   LOSING
# 9   France          H. Lloris      GKP   LOSING
# 6   France          R. Varane       CB   LOSING
# 20  France      N. Kant\u00e9      CDM   LOSING
# 21  France      N. Kant\u00e9      CDM   LOSING
# 28  France         B. Matuidi       LM   LOSING
# 25  France  L. Hern\u00e1ndez       LB   LOSING
# 2   France          B. Pavard       RB   LOSING
# 45  France          S. Umtiti       CB     DRAW
# 46  France          S. Umtiti       CB     DRAW
# 49  France      N. Kant\u00e9      CDM     DRAW
# 39  France          R. Varane       CB     DRAW
# 40  France          R. Varane       CB     DRAW
# 43  France           P. Pogba       CM     DRAW
# 41  France          R. Varane       CB     DRAW
# 38  France          B. Pavard       RB     DRAW
# 42  France          R. Varane       CB     DRAW
# 47  France          S. Umtiti       CB     DRAW
# 48  France          S. Umtiti       CB     DRAW
# 44  France           P. Pogba       CM     DRAW
# 52  France  L. Hern\u00e1ndez       LB     DRAW
# 53  France         B. Matuidi       LM     DRAW
# 50  France     K. Mbapp\u00e9       CF     DRAW
# 51  France     K. Mbapp\u00e9       CF     DRAW
# 69  France          B. Pavard       RB  LEADING
# 72  France          S. Umtiti       CB  LEADING
# 70  France          H. Lloris      GKP  LEADING
# 73  France          S. Umtiti       CB  LEADING
# 71  France          H. Lloris      GKP  LEADING
# 75  France      N. Kant\u00e9      CDM  LEADING
# 74  France       A. Griezmann       AM  LEADING
# 78  France         B. Matuidi       LM  LEADING
# 77  France          O. Giroud       CF  LEADING
# 76  France     K. Mbapp\u00e9       CF  LEADING

# %%
events_argentina_france = events_argentina[events_argentina['Team'] == 'France']

# %% [markdown]
# Uruguay - France

# %%
events_uruguay = events_before_goal_by_minutes(data, 'Uruguay', minutes=2)
events_uruguay
# Out:
#                   SubEvent                                               Tags  \
# 2              Simple pass                                           Accurate
# 5              Simple pass                                           Accurate
# 0              Simple pass                                           Accurate
# 11   Ground defending duel                       Take on right, Won, Accurate
# 7    Ground attacking duel                   Take on left, Lost, Not accurate
# 9                    Touch
# 10               High pass                                           Accurate
# 3                 Air duel                                      Won, Accurate
# 12                Air duel                                 Lost, Not accurate
# 8              Simple pass                             Interception, Accurate
# 14             Simple pass                                           Accurate
# 15                   Touch
# 16   Ground defending duel                 Sliding tackle, Lost, Not accurate
# 1    Ground attacking duel                                      Won, Accurate
# 17                    Foul                                        Yellow card
# 6          Free kick cross                             Assist, High, Accurate
# 13                Air duel                                 Lost, Not accurate
# 4                     Shot  Goal, Head/body, Opportunity, Position: Goal l...
# 23               Goal kick
# 19                Air duel                                 Lost, Not accurate
# 36                Air duel                                      Won, Accurate
# 29             Simple pass                                       Not accurate
# 32             Simple pass                             Fairplay, Not accurate
# 22             Simple pass                                           Accurate
# 24                  Launch                                           Accurate
# 37                Air duel                                      Won, Accurate
# 30                Air duel                                 Lost, Not accurate
# 20               Head pass                                       Not accurate
# 41            Acceleration                                           Accurate
# 42             Simple pass                                           Accurate
# 33  Ground loose ball duel                                 Lost, Not accurate
# 18  Ground loose ball duel                                      Won, Accurate
# 43   Ground defending duel                         Anticipated, Won, Accurate
# 31   Ground defending duel                                  Neutral, Accurate
# 44             Simple pass                                           Accurate
# 34             Simple pass                                           Accurate
# 38                   Touch                                        Missed ball
# 35             Simple pass                                           Accurate
# 39                   Touch
# 25   Ground defending duel                                      Won, Accurate
# 40   Ground defending duel                   Take on left, Lost, Not accurate
# 26            Acceleration                           Counter attack, Accurate
# 27             Simple pass                           Counter attack, Accurate
# 21             Simple pass                   Assist, Counter attack, Accurate
# 28                    Shot  Goal, Counter attack, Left foot, Opportunity, ...
#
#                       Match               Event     EventSec MatchPeriod  \
# 2   Uruguay - France, 0 - 2                Pass  2251.713452          1H
# 5   Uruguay - France, 0 - 2                Pass  2254.419370          1H
# 0   Uruguay - France, 0 - 2                Pass  2256.005491          1H
# 11  Uruguay - France, 0 - 2                Duel  2256.804754          1H
# 7   Uruguay - France, 0 - 2                Duel  2256.816574          1H
# 9   Uruguay - France, 0 - 2  Others on the ball  2258.435456          1H
# 10  Uruguay - France, 0 - 2                Pass  2261.590996          1H
# 3   Uruguay - France, 0 - 2                Duel  2264.572050          1H
# 12  Uruguay - France, 0 - 2                Duel  2264.638311          1H
# 8   Uruguay - France, 0 - 2                Pass  2265.718192          1H
# 14  Uruguay - France, 0 - 2                Pass  2269.008468          1H
# 15  Uruguay - France, 0 - 2  Others on the ball  2269.362781          1H
# 16  Uruguay - France, 0 - 2                Duel  2271.277547          1H
# 1   Uruguay - France, 0 - 2                Duel  2271.484081          1H
# 17  Uruguay - France, 0 - 2                Foul  2273.664532          1H
# 6   Uruguay - France, 0 - 2           Free Kick  2369.447264          1H
# 13  Uruguay - France, 0 - 2                Duel  2370.574308          1H
# 4   Uruguay - France, 0 - 2                Shot  2370.699238          1H
# 23  Uruguay - France, 0 - 2           Free Kick   835.938647          2H
# 19  Uruguay - France, 0 - 2                Duel   838.399086          2H
# 36  Uruguay - France, 0 - 2                Duel   838.637857          2H
# 29  Uruguay - France, 0 - 2                Pass   846.800232          2H
# 32  Uruguay - France, 0 - 2                Pass   911.317722          2H
# 22  Uruguay - France, 0 - 2                Pass   917.104962          2H
# 24  Uruguay - France, 0 - 2                Pass   920.558108          2H
# 37  Uruguay - France, 0 - 2                Duel   923.857204          2H
# 30  Uruguay - France, 0 - 2                Duel   923.882755          2H
# 20  Uruguay - France, 0 - 2                Pass   926.139298          2H
# 41  Uruguay - France, 0 - 2  Others on the ball   927.620581          2H
# 42  Uruguay - France, 0 - 2                Pass   930.959616          2H
# 33  Uruguay - France, 0 - 2                Duel   931.862696          2H
# 18  Uruguay - France, 0 - 2                Duel   931.899756          2H
# 43  Uruguay - France, 0 - 2                Duel   933.068363          2H
# 31  Uruguay - France, 0 - 2                Duel   933.365279          2H
# 44  Uruguay - France, 0 - 2                Pass   934.190860          2H
# 34  Uruguay - France, 0 - 2                Pass   935.060937          2H
# 38  Uruguay - France, 0 - 2  Others on the ball   935.207443          2H
# 35  Uruguay - France, 0 - 2                Pass   936.077399          2H
# 39  Uruguay - France, 0 - 2  Others on the ball   937.225753          2H
# 25  Uruguay - France, 0 - 2                Duel   938.453529          2H
# 40  Uruguay - France, 0 - 2                Duel   938.545362          2H
# 26  Uruguay - France, 0 - 2  Others on the ball   940.924987          2H
# 27  Uruguay - France, 0 - 2                Pass   943.411467          2H
# 21  Uruguay - France, 0 - 2                Pass   945.178696          2H
# 28  Uruguay - France, 0 - 2                Shot   947.251197          2H
#
#        Team             Player Position   Status
# 2    France          R. Varane       CB     DRAW
# 5    France           P. Pogba       CM     DRAW
# 0    France          B. Pavard       RB     DRAW
# 11  Uruguay      D. God\u00edn      NaN     DRAW
# 7    France     K. Mbapp\u00e9       CF     DRAW
# 9   Uruguay        L. Torreira      NaN     DRAW
# 10  Uruguay        L. Torreira      NaN     DRAW
# 3    France          R. Varane       CB     DRAW
# 12  Uruguay          C. Stuani      NaN     DRAW
# 8   Uruguay     L. Su\u00e1rez      NaN     DRAW
# 14  Uruguay          D. Laxalt      NaN     DRAW
# 15  Uruguay       R. Bentancur      NaN     DRAW
# 16  Uruguay       R. Bentancur      NaN     DRAW
# 1    France         C. Tolisso       CM     DRAW
# 17  Uruguay       R. Bentancur      NaN     DRAW
# 6    France       A. Griezmann       AM     DRAW
# 13  Uruguay          C. Stuani      NaN     DRAW
# 4    France          R. Varane       CB     DRAW
# 23   France          H. Lloris      GKP  LEADING
# 19   France         C. Tolisso       CM  LEADING
# 36  Uruguay     N. N\u00e1ndez      NaN  LEADING
# 29   France      N. Kant\u00e9      CDM  LEADING
# 32  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 22   France          R. Varane       CB  LEADING
# 24   France          H. Lloris      GKP  LEADING
# 37  Uruguay    J. Gim\u00e9nez      NaN  LEADING
# 30   France          O. Giroud       CF  LEADING
# 20   France         C. Tolisso       CM  LEADING
# 41  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 42  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 33  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 18   France          B. Pavard       RB  LEADING
# 43  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 31   France          O. Giroud       CF  LEADING
# 44  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 34  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 38  Uruguay          M. Vecino      NaN  LEADING
# 35  Uruguay        L. Torreira      NaN  LEADING
# 39  Uruguay          M. Vecino      NaN  LEADING
# 25   France           P. Pogba       CM  LEADING
# 40  Uruguay          M. Vecino      NaN  LEADING
# 26   France           P. Pogba       CM  LEADING
# 27   France           P. Pogba       CM  LEADING
# 21   France         C. Tolisso       CM  LEADING
# 28   France       A. Griezmann       AM  LEADING

# %%
events_uruguay_france = events_uruguay[events_uruguay['Team'] == 'France']

# %% [markdown]
# Belgium - France

# %%
events_belgium = events_before_goal_by_minutes(data, 'Belgium', minutes=2)
events_belgium
# Out:
#                  SubEvent                                               Tags  \
# 30            Simple pass                                           Accurate
# 22            Simple pass                                           Accurate
# 31            Simple pass                                           Accurate
# 29            Simple pass                                           Accurate
# 25            Simple pass                                           Accurate
# 19            Simple pass                                           Accurate
# 32            Simple pass                                           Accurate
# 26            Simple pass                                           Accurate
# 18            Simple pass                                           Accurate
# 33            Simple pass                                           Accurate
# 20                  Touch
# 21              High pass                              Through, Not accurate
# 0               Head pass                         Interception, Not accurate
# 27  Ground attacking duel                        Interception, Won, Accurate
# 13  Ground defending duel                                 Lost, Not accurate
# 23             Smart pass                              Through, Not accurate
# 4               Clearance                         Interception, Not accurate
# 24                  Touch                                       Interception
# 2               Goal kick
# 5             Simple pass                                           Accurate
# 16            Simple pass                                           Accurate
# 6             Simple pass                                           Accurate
# 3             Simple pass                                           Accurate
# 1             Simple pass                                           Accurate
# 11            Simple pass                                           Accurate
# 7             Simple pass                                           Accurate
# 12            Simple pass                                           Accurate
# 17            Simple pass                                           Accurate
# 14  Ground attacking duel                    Free space right, Won, Accurate
# 34  Ground defending duel                Free space left, Lost, Not accurate
# 15                   Shot     Right foot, Blocked, Opportunity, Not accurate
# 35                  Touch                                       Interception
# 10                 Corner                             Assist, High, Accurate
# 28               Air duel                                 Lost, Not accurate
# 8                Air duel                                      Won, Accurate
# 9                    Shot  Goal, Head/body, Opportunity, Position: Goal c...
#
#                       Match               Event    EventSec MatchPeriod  \
# 30  France - Belgium, 1 - 0                Pass  217.492584          2H
# 22  France - Belgium, 1 - 0                Pass  217.780138          2H
# 31  France - Belgium, 1 - 0                Pass  222.226767          2H
# 29  France - Belgium, 1 - 0                Pass  227.243636          2H
# 25  France - Belgium, 1 - 0                Pass  228.502728          2H
# 19  France - Belgium, 1 - 0                Pass  231.274477          2H
# 32  France - Belgium, 1 - 0                Pass  233.662077          2H
# 26  France - Belgium, 1 - 0                Pass  235.986662          2H
# 18  France - Belgium, 1 - 0                Pass  239.595786          2H
# 33  France - Belgium, 1 - 0                Pass  242.153579          2H
# 20  France - Belgium, 1 - 0  Others on the ball  244.013550          2H
# 21  France - Belgium, 1 - 0                Pass  246.618338          2H
# 0   France - Belgium, 1 - 0                Pass  247.533685          2H
# 27  France - Belgium, 1 - 0                Duel  249.741988          2H
# 13  France - Belgium, 1 - 0                Duel  250.002355          2H
# 23  France - Belgium, 1 - 0                Pass  251.421808          2H
# 4   France - Belgium, 1 - 0  Others on the ball  253.647871          2H
# 24  France - Belgium, 1 - 0  Others on the ball  255.998101          2H
# 2   France - Belgium, 1 - 0           Free Kick  275.249313          2H
# 5   France - Belgium, 1 - 0                Pass  278.729058          2H
# 16  France - Belgium, 1 - 0                Pass  279.349046          2H
# 6   France - Belgium, 1 - 0                Pass  281.916241          2H
# 3   France - Belgium, 1 - 0                Pass  284.663701          2H
# 1   France - Belgium, 1 - 0                Pass  288.558720          2H
# 11  France - Belgium, 1 - 0                Pass  293.119569          2H
# 7   France - Belgium, 1 - 0                Pass  296.252103          2H
# 12  France - Belgium, 1 - 0                Pass  297.398289          2H
# 17  France - Belgium, 1 - 0                Pass  300.399799          2H
# 14  France - Belgium, 1 - 0                Duel  302.210310          2H
# 34  France - Belgium, 1 - 0                Duel  302.393239          2H
# 15  France - Belgium, 1 - 0                Shot  302.735838          2H
# 35  France - Belgium, 1 - 0  Others on the ball  303.951718          2H
# 10  France - Belgium, 1 - 0           Free Kick  334.496557          2H
# 28  France - Belgium, 1 - 0                Duel  335.240263          2H
# 8   France - Belgium, 1 - 0                Duel  335.640221          2H
# 9   France - Belgium, 1 - 0                Shot  336.270432          2H
#
#        Team             Player Position Status
# 30  Belgium         V. Kompany      NaN   DRAW
# 22  Belgium       K. De Bruyne      NaN   DRAW
# 31  Belgium         V. Kompany      NaN   DRAW
# 29  Belgium          N. Chadli      NaN   DRAW
# 25  Belgium          A. Witsel      NaN   DRAW
# 19  Belgium    T. Alderweireld      NaN   DRAW
# 32  Belgium         V. Kompany      NaN   DRAW
# 26  Belgium          A. Witsel      NaN   DRAW
# 18  Belgium      J. Vertonghen      NaN   DRAW
# 33  Belgium         V. Kompany      NaN   DRAW
# 20  Belgium    T. Alderweireld      NaN   DRAW
# 21  Belgium    T. Alderweireld      NaN   DRAW
# 0    France          R. Varane       CB   DRAW
# 27  Belgium          A. Witsel      NaN   DRAW
# 13   France          O. Giroud       CF   DRAW
# 23  Belgium       K. De Bruyne      NaN   DRAW
# 4    France          S. Umtiti       CB   DRAW
# 24  Belgium       K. De Bruyne      NaN   DRAW
# 2    France          H. Lloris      GKP   DRAW
# 5    France          S. Umtiti       CB   DRAW
# 16   France         B. Matuidi       LM   DRAW
# 6    France          S. Umtiti       CB   DRAW
# 3    France          H. Lloris      GKP   DRAW
# 1    France          R. Varane       CB   DRAW
# 11   France      N. Kant\u00e9      CDM   DRAW
# 7    France          S. Umtiti       CB   DRAW
# 12   France  L. Hern\u00e1ndez       LB   DRAW
# 17   France         B. Matuidi       LM   DRAW
# 14   France          O. Giroud       CF   DRAW
# 34  Belgium         V. Kompany      NaN   DRAW
# 15   France          O. Giroud       CF   DRAW
# 35  Belgium         V. Kompany      NaN   DRAW
# 10   France       A. Griezmann       AM   DRAW
# 28  Belgium        M. Fellaini      NaN   DRAW
# 8    France          S. Umtiti       CB   DRAW
# 9    France          S. Umtiti       CB   DRAW

# %%
events_belgium_france = events_belgium[events_belgium['Team'] == 'France']

# %% [markdown]
# France - Croatia

# %%
events_croatia = events_before_goal_by_minutes(data, 'Croatia', minutes=2)
events_croatia
# Out:
#                  SubEvent                                               Tags  \
# 42                Penalty  Goal, Left foot, Position: Goal low left, Accu...
# 20            Simple pass                                           Accurate
# 27            Simple pass                                           Accurate
# 38            Simple pass                                           Accurate
# 22            Simple pass                                           Accurate
# ..                    ...                                                ...
# 61  Ground attacking duel                        Take on left, Won, Accurate
# 72  Ground defending duel  Take on right, Sliding tackle, Lost, Not accurate
# 62           Acceleration                                           Accurate
# 63            Simple pass                                           Accurate
# 56                   Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                       Match               Event     EventSec MatchPeriod  \
# 42  France - Croatia, 4 - 2           Free Kick  2278.895744          1H
# 20  France - Croatia, 4 - 2                Pass   696.186816          2H
# 27  France - Croatia, 4 - 2                Pass   702.212839          2H
# 38  France - Croatia, 4 - 2                Pass   704.050069          2H
# 22  France - Croatia, 4 - 2                Pass   707.191775          2H
# ..                      ...                 ...          ...         ...
# 61  France - Croatia, 4 - 2                Duel  1168.593984          2H
# 72  France - Croatia, 4 - 2                Duel  1168.593984          2H
# 62  France - Croatia, 4 - 2  Others on the ball  1170.985695          2H
# 63  France - Croatia, 4 - 2                Pass  1174.426589          2H
# 56  France - Croatia, 4 - 2                Shot  1177.058571          2H
#
#        Team                  Player Position   Status
# 42   France            A. Griezmann       AM     DRAW
# 20  Croatia  M. Mand\u017euki\u0107      NaN  LEADING
# 27  Croatia        \u0160. Vrsaljko      NaN  LEADING
# 38  Croatia               D. Lovren      NaN  LEADING
# 22  Croatia        M. Brozovi\u0107      NaN  LEADING
# ..      ...                     ...      ...      ...
# 61   France       L. Hern\u00e1ndez       LB  LEADING
# 72  Croatia  M. Mand\u017euki\u0107      NaN  LEADING
# 62   France       L. Hern\u00e1ndez       LB  LEADING
# 63   France       L. Hern\u00e1ndez       LB  LEADING
# 56   France          K. Mbapp\u00e9       CF  LEADING
#
# [103 rows x 10 columns]

# %%
events_croatia_france = events_croatia[events_croatia['Team'] == 'France']

# %% [markdown]
# France - Australia

# %%
events_australia = events_before_goal_by_minutes(data, 'Australia', minutes=2)
events_australia
# Out:
#   SubEvent                                               Tags  \
# 0  Penalty  Goal, Left foot, Position: Goal center right, ...
#
#                        Match      Event    EventSec MatchPeriod    Team  \
# 0  France - Australia, 2 - 1  Free Kick  730.009243          2H  France
#
#          Player Position Status
# 0  A. Griezmann       AM   DRAW

# %%
events_australia_france = events_australia[events_australia['Team'] == 'France']

# %% [markdown]
# France - Peru

# %%
events_peru = events_before_goal_by_minutes(data, 'Peru', minutes=2)
events_peru
# Out:
#                   SubEvent                                               Tags  \
# 28             Simple pass                                           Accurate
# 15             Simple pass                                           Accurate
# 5              Simple pass                                           Accurate
# 0              Simple pass                                           Accurate
# 25             Simple pass                                       Not accurate
# ..                     ...                                                ...
# 52  Ground loose ball duel                 Sliding tackle, Lost, Not accurate
# 10              Smart pass                        Key pass, Through, Accurate
# 32                    Shot      Left foot, Blocked, Opportunity, Not accurate
# 46                   Touch                                       Interception
# 27                    Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                    Match               Event     EventSec MatchPeriod    Team  \
# 28  France - Peru, 1 - 0                Pass  1907.657794          1H  France
# 15  France - Peru, 1 - 0                Pass  1910.006757          1H  France
# 5   France - Peru, 1 - 0                Pass  1912.559975          1H  France
# 0   France - Peru, 1 - 0                Pass  1913.757697          1H  France
# 25  France - Peru, 1 - 0                Pass  1917.304816          1H  France
# ..                   ...                 ...          ...         ...     ...
# 52  France - Peru, 1 - 0                Duel  2019.978058          1H    Peru
# 10  France - Peru, 1 - 0                Pass  2022.354070          1H  France
# 32  France - Peru, 1 - 0                Shot  2023.580214          1H  France
# 46  France - Peru, 1 - 0  Others on the ball  2024.690943          1H    Peru
# 27  France - Peru, 1 - 0                Shot  2025.334462          1H  France
#
#                Player Position Status
# 28  L. Hern\u00e1ndez       LB   DRAW
# 15      N. Kant\u00e9      CDM   DRAW
# 5           R. Varane       CB   DRAW
# 0           B. Pavard       RB   DRAW
# 25     K. Mbapp\u00e9       CF   DRAW
# ..                ...      ...    ...
# 52        P. Guerrero      NaN   DRAW
# 10           P. Pogba       CM   DRAW
# 32          O. Giroud       CF   DRAW
# 46  A. Rodr\u00edguez      NaN   DRAW
# 27     K. Mbapp\u00e9       CF   DRAW
#
# [65 rows x 10 columns]

# %%
events_peru_france = events_peru[events_peru['Team'] == 'France']

# %%
all_events_before_goals = pd.concat([events_argentina, events_uruguay, events_croatia, events_australia, events_belgium, events_peru], ignore_index=True)
all_events_before_goals
# Out:
#                    SubEvent  \
# 0                   Penalty
# 1               Simple pass
# 2               Simple pass
# 3     Ground defending duel
# 4     Ground attacking duel
# ..                      ...
# 343  Ground loose ball duel
# 344              Smart pass
# 345                    Shot
# 346                   Touch
# 347                    Shot
#
#                                                   Tags  \
# 0    Goal, Left foot, Position: Goal low center, Ac...
# 1                                             Accurate
# 2                                         Not accurate
# 3            Take on right, Anticipated, Won, Accurate
# 4       Take on left, Anticipation, Lost, Not accurate
# ..                                                 ...
# 343                 Sliding tackle, Lost, Not accurate
# 344                        Key pass, Through, Accurate
# 345      Left foot, Blocked, Opportunity, Not accurate
# 346                                       Interception
# 347  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 1    France - Argentina, 4 - 3                Pass   589.283334          2H
# 2    France - Argentina, 4 - 3                Pass   593.816026          2H
# 3    France - Argentina, 4 - 3                Duel   594.475207          2H
# 4    France - Argentina, 4 - 3                Duel   594.837089          2H
# ..                         ...                 ...          ...         ...
# 343       France - Peru, 1 - 0                Duel  2019.978058          1H
# 344       France - Peru, 1 - 0                Pass  2022.354070          1H
# 345       France - Peru, 1 - 0                Shot  2023.580214          1H
# 346       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 347       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#           Team             Player Position  Status
# 0       France       A. Griezmann       AM    DRAW
# 1       France          R. Varane       CB  LOSING
# 2       France     K. Mbapp\u00e9       CF  LOSING
# 3       France           P. Pogba       CM  LOSING
# 4    Argentina      N. Tagliafico      NaN  LOSING
# ..         ...                ...      ...     ...
# 343       Peru        P. Guerrero      NaN    DRAW
# 344     France           P. Pogba       CM    DRAW
# 345     France          O. Giroud       CF    DRAW
# 346       Peru  A. Rodr\u00edguez      NaN    DRAW
# 347     France     K. Mbapp\u00e9       CF    DRAW
#
# [348 rows x 10 columns]

# %%
filtered_events = all_events_before_goals[
    ~(
        (all_events_before_goals['Event'] == 'Duel') & 
        (all_events_before_goals['Tags'].str.contains("Lost"))
    )
]

filtered_events
# Out:
#                    SubEvent  \
# 0                   Penalty
# 1               Simple pass
# 2               Simple pass
# 3     Ground defending duel
# 5               Simple pass
# ..                      ...
# 342  Ground loose ball duel
# 344              Smart pass
# 345                    Shot
# 346                   Touch
# 347                    Shot
#
#                                                   Tags  \
# 0    Goal, Left foot, Position: Goal low center, Ac...
# 1                                             Accurate
# 2                                         Not accurate
# 3            Take on right, Anticipated, Won, Accurate
# 5                                             Accurate
# ..                                                 ...
# 342                                      Won, Accurate
# 344                        Key pass, Through, Accurate
# 345      Left foot, Blocked, Opportunity, Not accurate
# 346                                       Interception
# 347  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3           Free Kick   761.289657          1H
# 1    France - Argentina, 4 - 3                Pass   589.283334          2H
# 2    France - Argentina, 4 - 3                Pass   593.816026          2H
# 3    France - Argentina, 4 - 3                Duel   594.475207          2H
# 5    France - Argentina, 4 - 3                Pass   597.481241          2H
# ..                         ...                 ...          ...         ...
# 342       France - Peru, 1 - 0                Duel  2019.807640          1H
# 344       France - Peru, 1 - 0                Pass  2022.354070          1H
# 345       France - Peru, 1 - 0                Shot  2023.580214          1H
# 346       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 347       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#        Team             Player Position  Status
# 0    France       A. Griezmann       AM    DRAW
# 1    France          R. Varane       CB  LOSING
# 2    France     K. Mbapp\u00e9       CF  LOSING
# 3    France           P. Pogba       CM  LOSING
# 5    France          B. Pavard       RB  LOSING
# ..      ...                ...      ...     ...
# 342  France           P. Pogba       CM    DRAW
# 344  France           P. Pogba       CM    DRAW
# 345  France          O. Giroud       CF    DRAW
# 346    Peru  A. Rodr\u00edguez      NaN    DRAW
# 347  France     K. Mbapp\u00e9       CF    DRAW
#
# [308 rows x 10 columns]

# %%
all_events_before_goals['Match'].unique()
# Out:
# array(['France - Argentina, 4 - 3', 'Uruguay - France, 0 - 2',
#        'France - Croatia, 4 - 2', 'France - Australia, 2 - 1',
#        'France - Belgium, 1 - 0', 'France - Peru, 1 - 0'], dtype=object)

# %% [markdown]
# ##We have shot, freekick shot, cross , freekick cross, corner in subevent which are more exciting for now.

# %%
def sort_by_match(data):
    return data.sort_values(by=['Match','MatchPeriod', 'EventSec'])

all_events_before_goals_sorted = sort_by_match(all_events_before_goals)
filtered_events_sorted = sort_by_match(filtered_events)

# %% [markdown]
# We have finished our data preparation. Time to create an structured XES file

# %%
from datetime import datetime, timedelta

def create_events_before_goal_xes_file(data, filename="output.xes", checkOn: str = "org:resource"):
    def safe_str(value):
        """Safely convert value to string, handling NaN."""
        if pd.isna(value):
            return ""
        return str(value)

    base_datetime = datetime(2020, 1, 1)  # Arbitrary base date for timestamps

    with open(filename, 'w') as f:
        # Write XML declaration and log opening tag
        f.write('<?xml version="1.0" encoding="UTF-8" ?>\n')
        f.write('<log xes.version="1.0" xes.features="nested-attributes" openxes.version="1.0RC7" xmlns="http://www.xes-standard.org/">\n')
        f.write(f'<classifier name="Activity_Resource" keys="{checkOn}"/>\n')
        f.write('<classifier name="Default" keys="concept:name"/>\n')

        current_trace = []  # Collect events for the current trace
        last_opponent_action = None  # Store the last action by the opponent
        in_trace = False  # Track if we're inside a trace

        for idx, row in data.iterrows():
            if row['Team'] == 'France':
                # Add the event to the current trace
                current_trace.append({
                    'Player': row['Player'],
                    'Position': row['Position'],
                    'Event': row['Event'],
                    'EventSec': row['EventSec'],
                    'SubEvent': row['SubEvent'],
                    'MatchPeriod': row['MatchPeriod'],
                    'Tags': row['Tags'],
                    'Match': row['Match'],
                    'Status': row['Status'],
                })
                in_trace = True

                # End trace if the current event is a goal
                if "Goal" in safe_str(row['Tags']):
                    # Write the trace to the file
                    if current_trace:
                        f.write('  <trace>\n')
                        f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                        f.write(f'    <string key="custom:endReason" value="{safe_str(row["Event"])}" />\n')

                        for event in current_trace:
                            event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                            event_timestamp = event_datetime.isoformat()

                            f.write('    <event>\n')
                            f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                            f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                            f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                            f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                            f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                            f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                            f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                            f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                            f.write(f'      <string key="custom:status" value="{safe_str(event["Status"])}" />\n')
                            f.write('    </event>\n')

                        f.write('  </trace>\n')

                    # Reset trace after writing
                    current_trace = []
                    in_trace = False
            else:
                # Handle events by the opponent
                if in_trace:
                    # Write the current trace before switching possession
                    if current_trace:
                        f.write('  <trace>\n')
                        f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                        f.write(f'    <string key="custom:endReason" value="{safe_str(current_trace[-1]["Event"])}" />\n')

                        for event in current_trace:
                            event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                            event_timestamp = event_datetime.isoformat()

                            f.write('    <event>\n')
                            f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                            f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                            f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                            f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                            f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                            f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                            f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                            f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                            f.write(f'      <string key="custom:status" value="{safe_str(event["Status"])}" />\n')
                            f.write('    </event>\n')

                        f.write('  </trace>\n')

                    # Reset trace variables
                    current_trace = []
                    in_trace = False

                last_opponent_action = row['Event']

        # Write remaining trace if any
        if current_trace:
            f.write('  <trace>\n')
            f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
            f.write(f'    <string key="custom:endReason" value="{safe_str(current_trace[-1]["Event"])}" />\n')

            for event in current_trace:
                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                event_timestamp = event_datetime.isoformat()

                f.write('    <event>\n')
                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                f.write(f'      <string key="custom:status" value="{safe_str(event["Status"])}" />\n')
                f.write('    </event>\n')

            f.write('  </trace>\n')

        f.write('</log>\n')

# %%
create_events_before_goal_xes_file(sort_by_match(all_events_before_goals_sorted), filename="all_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_belgium), filename="belgium_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_argentina), filename="argentina_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_uruguay), filename="uruguay_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_croatia), filename="croatia_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_australia), filename="australia_events_before_goal.xes")
create_events_before_goal_xes_file(sort_by_match(events_peru), filename="peru_events_before_goal.xes")
