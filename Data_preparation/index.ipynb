# %%
import pandas as pd
import ast

# %%
events_world_cup =pd.read_csv('../events_World_Cup.csv')
teams = pd.read_csv('../teams.csv')
tags2name = pd.read_csv('../tags2name.csv')
playerrank = pd.read_csv('../playerank.csv')
players = pd.read_csv('../players.csv')
matches_world_cup = pd.read_csv('../matches_World_Cup.csv')

# %% [markdown]
# Lets filter the unrequired columns

# %%
events_world_cup = events_world_cup[['subEventName', 'tags', 'playerId', 'matchId', 'eventName', 'teamId', 'eventSec', 'matchPeriod']]
players = players[['wyId', 'shortName']]
tags2name = tags2name[['Tag', 'Description']]
teams = teams[['wyId', 'officialName', 'type']]
playerrank = playerrank[['playerId', 'roleCluster']]

# %% [markdown]
# Start filtering the data

# %%
# Only national teams
teams = teams[teams['type'] == 'national']

# Only matches where France has played.
matches_world_cup = matches_world_cup[matches_world_cup['label'].str.contains("France")]

# Only events from the matches where France has played.
events_world_cup = events_world_cup[events_world_cup['matchId'].isin(matches_world_cup['wyId'])]

events_world_cup
# Out:
#        subEventName            tags  playerId  matchId           eventName  \
# 18813   Simple pass  [{'id': 1801}]    238055  2057966                Pass
# 18814     High pass  [{'id': 1802}]     61395  2057966                Pass
# 18815      Throw in  [{'id': 1801}]    340646  2057966           Free Kick
# 18816   Simple pass  [{'id': 1801}]    209091  2057966                Pass
# 18817        Launch  [{'id': 1802}]    340646  2057966                Pass
# ...             ...             ...       ...      ...                 ...
# 101751    High pass  [{'id': 1802}]     69396  2058017                Pass
# 101752    Clearance  [{'id': 1802}]      3309  2058017  Others on the ball
# 101753     Throw in  [{'id': 1801}]     69968  2058017           Free Kick
# 101754  Simple pass  [{'id': 1801}]      3476  2058017                Pass
# 101755        Touch              []     14812  2058017  Others on the ball
#
#         teamId     eventSec matchPeriod
# 18813     8493     1.435354          1H
# 18814     8493     3.978396          1H
# 18815     4418    15.608867          1H
# 18816     4418    16.385084          1H
# 18817     4418    17.214485          1H
# ...        ...          ...         ...
# 101751    9598  2964.715715          2H
# 101752    4418  2967.926784          2H
# 101753    9598  2972.985039          2H
# 101754    9598  2978.301867          2H
# 101755    9598  2979.084611          2H
#
# [10843 rows x 8 columns]

# %%
# Merge match name
data = pd.merge(events_world_cup, teams, left_on='teamId', right_on='wyId')
data
# Out:
#       subEventName                         tags  playerId  matchId  \
# 0      Simple pass               [{'id': 1801}]    238055  2057966
# 1        High pass               [{'id': 1802}]     61395  2057966
# 2        Head pass               [{'id': 1802}]     61425  2057966
# 3        High pass               [{'id': 1801}]     62389  2057966
# 4         Air duel  [{'id': 701}, {'id': 1802}]     16151  2057966
# ...            ...                          ...       ...      ...
# 10838        Touch                           []     69396  2058017
# 10839    High pass               [{'id': 1802}]     69396  2058017
# 10840     Throw in               [{'id': 1801}]     69968  2058017
# 10841  Simple pass               [{'id': 1801}]      3476  2058017
# 10842        Touch                           []     14812  2058017
#
#                 eventName  teamId     eventSec matchPeriod  wyId officialName  \
# 0                    Pass    8493     1.435354          1H  8493    Australia
# 1                    Pass    8493     3.978396          1H  8493    Australia
# 2                    Pass    8493    19.920463          1H  8493    Australia
# 3                    Pass    8493    26.371362          1H  8493    Australia
# 4                    Duel    8493    27.942092          1H  8493    Australia
# ...                   ...     ...          ...         ...   ...          ...
# 10838  Others on the ball    9598  2960.803153          2H  9598      Croatia
# 10839                Pass    9598  2964.715715          2H  9598      Croatia
# 10840           Free Kick    9598  2972.985039          2H  9598      Croatia
# 10841                Pass    9598  2978.301867          2H  9598      Croatia
# 10842  Others on the ball    9598  2979.084611          2H  9598      Croatia
#
#            type
# 0      national
# 1      national
# 2      national
# 3      national
# 4      national
# ...         ...
# 10838  national
# 10839  national
# 10840  national
# 10841  national
# 10842  national
#
# [10843 rows x 11 columns]

# %%
# Merge player name
data = pd.merge(data, players, left_on='playerId', right_on='wyId')
data
# Out:
#                  subEventName                                      tags  \
# 0                 Simple pass                            [{'id': 1801}]
# 1                 Simple pass                            [{'id': 1801}]
# 2      Ground loose ball duel               [{'id': 701}, {'id': 1802}]
# 3                   Head pass                            [{'id': 1801}]
# 4                    Air duel               [{'id': 701}, {'id': 1802}]
# ...                       ...                                       ...
# 10838             Simple pass                            [{'id': 1801}]
# 10839   Ground attacking duel  [{'id': 502}, {'id': 703}, {'id': 1801}]
# 10840             Simple pass                            [{'id': 1802}]
# 10841             Simple pass                            [{'id': 1801}]
# 10842   Ground defending duel               [{'id': 703}, {'id': 1801}]
#
#        playerId  matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0        238055  2057966      Pass    8493     1.435354          1H    8493
# 1        238055  2057966      Pass    8493   318.452504          1H    8493
# 2        238055  2057966      Duel    8493   622.800480          1H    8493
# 3        238055  2057966      Pass    8493  1089.881235          1H    8493
# 4        238055  2057966      Duel    8493  1310.158067          1H    8493
# ...         ...      ...       ...     ...          ...         ...     ...
# 10838     69411  2058017      Pass    9598  2888.451480          2H    9598
# 10839    135810  2058017      Duel    9598  2398.932619          2H    9598
# 10840    135810  2058017      Pass    9598  2400.002448          2H    9598
# 10841    135810  2058017      Pass    9598  2567.478676          2H    9598
# 10842    135810  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
# Merge tags

def map_tags_to_desc(tag_list):
    descriptions = []
    for tag in tag_list:
        tag_id = tag['id']
        description = tags2name.loc[tags2name['Tag'] == tag_id, 'Description'].values
        if len(description) > 0:
            descriptions.append(description[0])
    return descriptions

data['tags'] = data['tags'].apply(lambda x: map_tags_to_desc(ast.literal_eval(x)))
data
# Out:
#                  subEventName                              tags  playerId  \
# 0                 Simple pass                        [Accurate]    238055
# 1                 Simple pass                        [Accurate]    238055
# 2      Ground loose ball duel              [Lost, Not accurate]    238055
# 3                   Head pass                        [Accurate]    238055
# 4                    Air duel              [Lost, Not accurate]    238055
# ...                       ...                               ...       ...
# 10838             Simple pass                        [Accurate]     69411
# 10839   Ground attacking duel  [Free space left, Won, Accurate]    135810
# 10840             Simple pass                    [Not accurate]    135810
# 10841             Simple pass                        [Accurate]    135810
# 10842   Ground defending duel                   [Won, Accurate]    135810
#
#        matchId eventName  teamId     eventSec matchPeriod  wyId_x  \
# 0      2057966      Pass    8493     1.435354          1H    8493
# 1      2057966      Pass    8493   318.452504          1H    8493
# 2      2057966      Duel    8493   622.800480          1H    8493
# 3      2057966      Pass    8493  1089.881235          1H    8493
# 4      2057966      Duel    8493  1310.158067          1H    8493
# ...        ...       ...     ...          ...         ...     ...
# 10838  2058017      Pass    9598  2888.451480          2H    9598
# 10839  2058017      Duel    9598  2398.932619          2H    9598
# 10840  2058017      Pass    9598  2400.002448          2H    9598
# 10841  2058017      Pass    9598  2567.478676          2H    9598
# 10842  2058017      Duel    9598  2752.746051          2H    9598
#
#       officialName      type  wyId_y         shortName
# 0        Australia  national  238055        A. Nabbout
# 1        Australia  national  238055        A. Nabbout
# 2        Australia  national  238055        A. Nabbout
# 3        Australia  national  238055        A. Nabbout
# 4        Australia  national  238055        A. Nabbout
# ...            ...       ...     ...               ...
# 10838      Croatia  national   69411  A. Kramari\u0107
# 10839      Croatia  national  135810          M. Pjaca
# 10840      Croatia  national  135810          M. Pjaca
# 10841      Croatia  national  135810          M. Pjaca
# 10842      Croatia  national  135810          M. Pjaca
#
# [10843 rows x 13 columns]

# %%
data = data.drop(columns=['playerId', 'teamId', 'type', 'wyId_y', 'wyId_x'])

# Replace matchId with match label
data = data.merge(matches_world_cup[['wyId', 'label']], left_on='matchId', right_on='wyId', how='left')

data['matchId'] = data['label']
data = data.drop(columns=['label', 'wyId'])

data = data.rename(columns=
                   {'officialName': 'Team',
                    'shortName': 'Player',
                    'matchId' : 'Match',
                    'eventName': 'Event',
                    'tags': 'Tags', 
                    'matchPeriod': 'MatchPeriod',
                    'eventSec': 'EventSec',
                    'subEventName': 'SubEvent'}
                    )
data
# Out:
#                      SubEvent                              Tags  \
# 0                 Simple pass                        [Accurate]
# 1                 Simple pass                        [Accurate]
# 2      Ground loose ball duel              [Lost, Not accurate]
# 3                   Head pass                        [Accurate]
# 4                    Air duel              [Lost, Not accurate]
# ...                       ...                               ...
# 10838             Simple pass                        [Accurate]
# 10839   Ground attacking duel  [Free space left, Won, Accurate]
# 10840             Simple pass                    [Not accurate]
# 10841             Simple pass                        [Accurate]
# 10842   Ground defending duel                   [Won, Accurate]
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
data['Tags'] = data['Tags'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
data
# Out:
#                      SubEvent                            Tags  \
# 0                 Simple pass                        Accurate
# 1                 Simple pass                        Accurate
# 2      Ground loose ball duel              Lost, Not accurate
# 3                   Head pass                        Accurate
# 4                    Air duel              Lost, Not accurate
# ...                       ...                             ...
# 10838             Simple pass                        Accurate
# 10839   Ground attacking duel  Free space left, Won, Accurate
# 10840             Simple pass                    Not accurate
# 10841             Simple pass                        Accurate
# 10842   Ground defending duel                   Won, Accurate
#
#                            Match Event     EventSec MatchPeriod       Team  \
# 0      France - Australia, 2 - 1  Pass     1.435354          1H  Australia
# 1      France - Australia, 2 - 1  Pass   318.452504          1H  Australia
# 2      France - Australia, 2 - 1  Duel   622.800480          1H  Australia
# 3      France - Australia, 2 - 1  Pass  1089.881235          1H  Australia
# 4      France - Australia, 2 - 1  Duel  1310.158067          1H  Australia
# ...                          ...   ...          ...         ...        ...
# 10838    France - Croatia, 4 - 2  Pass  2888.451480          2H    Croatia
# 10839    France - Croatia, 4 - 2  Duel  2398.932619          2H    Croatia
# 10840    France - Croatia, 4 - 2  Pass  2400.002448          2H    Croatia
# 10841    France - Croatia, 4 - 2  Pass  2567.478676          2H    Croatia
# 10842    France - Croatia, 4 - 2  Duel  2752.746051          2H    Croatia
#
#                  Player
# 0            A. Nabbout
# 1            A. Nabbout
# 2            A. Nabbout
# 3            A. Nabbout
# 4            A. Nabbout
# ...                 ...
# 10838  A. Kramari\u0107
# 10839          M. Pjaca
# 10840          M. Pjaca
# 10841          M. Pjaca
# 10842          M. Pjaca
#
# [10843 rows x 8 columns]

# %%
grouped  = data.groupby('Match').size().reset_index(name='count')

# Data per match
grouped
# Out:
#                        Match  count
# 0    Denmark - France, 0 - 0   1581
# 1  France - Argentina, 4 - 3   1426
# 2  France - Australia, 2 - 1   1514
# 3    France - Belgium, 1 - 0   1588
# 4    France - Croatia, 4 - 2   1459
# 5       France - Peru, 1 - 0   1668
# 6    Uruguay - France, 0 - 2   1607

# %%
# All relevant french players
french_players = data[data['Team'] == 'France']['Player'].unique().tolist()
french_players
# Out:
# ['B. Pavard',
#  'C. Tolisso',
#  'R. Varane',
#  'H. Lloris',
#  'P. Pogba',
#  'S. Umtiti',
#  'A. Griezmann',
#  'N. Kant\\u00e9',
#  'K. Mbapp\\u00e9',
#  'L. Hern\\u00e1ndez',
#  'O. Demb\\u00e9l\\u00e9',
#  'N. Fekir',
#  'O. Giroud',
#  'B. Matuidi',
#  "S. N'Zonzi",
#  'D. Sidib\\u00e9',
#  'P. Kimpembe',
#  'T. Lemar',
#  'S. Mandanda',
#  'B. Mendy',
#  'F. Thauvin']

# %%
# Manually map the players to their respective postions
player_position_mapping = {
    'B. Pavard': 'RB',
    'C. Tolisso': 'CM',
    'R. Varane': 'CB',
    'H. Lloris': 'GKP',
    'P. Pogba': 'CM',
    'S. Umtiti': 'CB',
    'A. Griezmann': 'AM',
    'N. Kant\\u00e9': 'CDM',
    'K. Mbapp\\u00e9': 'CF',
    'L. Hern\\u00e1ndez': 'LB',
    'O. Demb\\u00e9l\\u00e9': 'RW',
    'N. Fekir': 'AM',
    'O. Giroud': 'CF',
    'B. Matuidi': 'LM',
    "S. N'Zonzi": 'CM',
    'D. Sidibé': 'RB',
    'P. Kimpembe': 'CB',
    'T. Lemar': 'LW',
    'S. Mandanda': 'GKP',
    'B. Mendy': 'LB',
    'F. Thauvin': 'RW',
    'D. Sidib\\u00e9': 'RB',
}

# Map the Position based on Player names
data['Position'] = data['Player'].map(player_position_mapping)

data[data['Team'] == 'France']
# Out:
#          SubEvent                              Tags  \
# 700      Throw in                          Accurate
# 701        Launch                      Not accurate
# 702   Simple pass                          Accurate
# 703   Simple pass                          Accurate
# 704   Simple pass                          Accurate
# ...           ...                               ...
# 6020  Simple pass                          Accurate
# 6021        Cross  Left foot, Blocked, Not accurate
# 6022     Throw in                          Accurate
# 6023  Simple pass                          Accurate
# 6024     Air duel                     Won, Accurate
#
#                           Match      Event     EventSec MatchPeriod    Team  \
# 700   France - Australia, 2 - 1  Free Kick    15.608867          1H  France
# 701   France - Australia, 2 - 1       Pass    17.214485          1H  France
# 702   France - Australia, 2 - 1       Pass    32.884277          1H  France
# 703   France - Australia, 2 - 1       Pass    54.866585          1H  France
# 704   France - Australia, 2 - 1       Pass    75.441589          1H  France
# ...                         ...        ...          ...         ...     ...
# 6020    Denmark - France, 0 - 0       Pass  2848.941221          2H  France
# 6021    Denmark - France, 0 - 0       Pass  2853.514985          2H  France
# 6022    Denmark - France, 0 - 0  Free Kick  2859.488457          2H  France
# 6023  France - Argentina, 4 - 3       Pass  2613.230156          2H  France
# 6024  France - Argentina, 4 - 3       Duel  2622.866067          2H  France
#
#           Player Position
# 700    B. Pavard       RB
# 701    B. Pavard       RB
# 702    B. Pavard       RB
# 703    B. Pavard       RB
# 704    B. Pavard       RB
# ...          ...      ...
# 6020    B. Mendy       LB
# 6021    B. Mendy       LB
# 6022    B. Mendy       LB
# 6023  F. Thauvin       RW
# 6024  F. Thauvin       RW
#
# [5325 rows x 9 columns]

# %%
data['SubEvent'] = data['SubEvent'].fillna('')

# %%
data["Status"] = "DRAW"

# France vs Australia

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

# Second goal conceded by France
mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (17*60))
)
data.loc[mask, 'Status'] = 'DRAW'

mask = (
    data['Match'].str.contains('France - Australia', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (36*60))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Denmark is already prepopulated with draw

# France v Peru

# First goal scored by France
mask = (
    data['Match'].str.contains('France - Peru', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (35*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France vs Argentina

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (14*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (42*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'

#Conceded
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (4*60 ))
)
data.loc[mask, 'Status'] = 'LOSING'

#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (13*60 ))
)
data.loc[mask, 'Status'] = 'DRAW'


#Scored
mask = (
    data['Match'].str.contains('France - Argentina', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (20*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# Uruguay vs France

#Scored
mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (40*60 ))
)

mask = (
    data['Match'].str.contains('Uruguay - France', na=False) & 
    (data['MatchPeriod'] == '2H'))
data.loc[mask, 'Status'] = 'LEADING'
# Belgium vs France

#Scored
mask = (
    data['Match'].str.contains('France - Belgium', na=False) & 
    (data['MatchPeriod'] == '2H') & 
    (data['EventSec'] > (7*60 ))
)
data.loc[mask, 'Status'] = 'LEADING'
# France - Croatia

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (20*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Conceeded
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (29*60))
)
data.loc[mask, 'Status'] = 'DRAW'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '1H') & 
    (data['EventSec'] > (39*60))
)
data.loc[mask, 'Status'] = 'LEADING'

#Scored
mask = (
    data['Match'].str.contains('France - Croatia', na=False) & 
    (data['MatchPeriod'] == '2H') 
)
data.loc[mask, 'Status'] = 'LEADING'

# %% [markdown]
# ### Events before goals by given minute

# %%
def events_before_goal_by_minutes(data, opponent_team, minutes=1):  
    # Determine the times of all goals by France
    goal_times = data[
        data['Match'].str.contains(opponent_team, na=False) &
        (data['Tags'].str.contains('Goal,', na=False)) & 
        (data['Tags'].str.contains('Accurate', na=False))
    ].EventSec
    
    if not goal_times.empty:
        events_before_goals = []
        
        for goal_time in goal_times:
            # Filter the events for the specified number of minutes before the goal (including the goal)
            events_before_goal = data[
                data['Match'].str.contains(opponent_team, na=False) &
                (data['EventSec'] >= goal_time - minutes * 60) & 
                (data['EventSec'] <= goal_time)
            ]
            
            events_before_goals.append(events_before_goal)
        
        # Concatenate all the events before each goal
        events_before_goal_df = pd.concat(events_before_goals, ignore_index=True)
        
        return events_before_goal_df.sort_values(by='EventSec')
    
    else:
        # Return an empty DataFrame if no goals are found
        return pd.DataFrame(columns=data.columns)

# %% [markdown]
# France - Denmark

# %%
events_denmark = events_before_goal_by_minutes(data, 'Denmark', minutes=1)
events_denmark
# Out:
# Empty DataFrame
# Columns: [SubEvent, Tags, Match, Event, EventSec, MatchPeriod, Team, Player, Position, Status]
# Index: []

# %% [markdown]
# France - Argentina

# %%
events_argentina = events_before_goal_by_minutes(data, 'Argentina', minutes=1)
events_argentina
# Out:
#         SubEvent                                               Tags  \
# 106        Touch
# 107  Simple pass                                           Accurate
# 112  Simple pass                                           Accurate
# 108  Simple pass                                           Accurate
# 103    High pass                                           Accurate
# ..           ...                                                ...
# 193  Simple pass                                           Accurate
# 162     Throw in                                       Not accurate
# 199  Simple pass                                           Accurate
# 194    High pass                          Assist, Through, Accurate
# 202         Shot  Goal, Head/body, Opportunity, Position: Goal l...
#
#                          Match               Event     EventSec MatchPeriod  \
# 106  France - Argentina, 4 - 3  Others on the ball    98.151883          1H
# 107  France - Argentina, 4 - 3                Pass   101.848230          1H
# 112  France - Argentina, 4 - 3                Pass   103.005443          1H
# 108  France - Argentina, 4 - 3                Pass   104.546703          1H
# 103  France - Argentina, 4 - 3                Pass   106.237017          1H
# ..                         ...                 ...          ...         ...
# 193  France - Argentina, 4 - 3                Pass  2814.852677          2H
# 162  France - Argentina, 4 - 3           Free Kick  2817.990344          1H
# 199  France - Argentina, 4 - 3                Pass  2818.764204          2H
# 194  France - Argentina, 4 - 3                Pass  2821.424243          2H
# 202  France - Argentina, 4 - 3                Shot  2823.552153          2H
#
#           Team                 Player Position   Status
# 106  Argentina             G. Mercado      NaN     DRAW
# 107  Argentina             G. Mercado      NaN     DRAW
# 112  Argentina          C. Pav\u00f3n      NaN     DRAW
# 108  Argentina             G. Mercado      NaN     DRAW
# 103  Argentina            N. Otamendi      NaN     DRAW
# ..         ...                    ...      ...      ...
# 193  Argentina               L. Messi      NaN  LEADING
# 162     France              B. Pavard       RB     DRAW
# 199  Argentina  \u00c1. di Mar\u00eda      NaN  LEADING
# 194  Argentina               L. Messi      NaN  LEADING
# 202  Argentina         S. Ag\u00fcero      NaN  LEADING
#
# [204 rows x 10 columns]

# %% [markdown]
# Uruguay - France

# %%
events_uruguay = events_before_goal_by_minutes(data, 'Uruguay', minutes=1)
events_uruguay
# Out:
#                   SubEvent                                               Tags  \
# 37               Head pass                                 Key pass, Accurate
# 36                    Shot  Head/body, Opportunity, Position: Out high cen...
# 42             Simple pass                             Fairplay, Not accurate
# 28             Simple pass                                           Accurate
# 29                  Launch                                           Accurate
# 49                Air duel                                      Won, Accurate
# 40                Air duel                                 Lost, Not accurate
# 26               Head pass                                       Not accurate
# 55            Acceleration                                           Accurate
# 50               Goal kick
# 56             Simple pass                                           Accurate
# 47  Ground loose ball duel                                  Neutral, Accurate
# 43  Ground loose ball duel                                 Lost, Not accurate
# 24  Ground loose ball duel                                      Won, Accurate
# 48                Air duel                                      Won, Accurate
# 25                Air duel                                 Lost, Not accurate
# 57   Ground defending duel                         Anticipated, Won, Accurate
# 41   Ground defending duel                                  Neutral, Accurate
# 58             Simple pass                                           Accurate
# 33               Head pass                                       Not accurate
# 44             Simple pass                                           Accurate
# 52                   Touch                                        Missed ball
# 46             Simple pass                                           Accurate
# 51               Head pass                                       Not accurate
# 53                   Touch
# 30   Ground defending duel                                      Won, Accurate
# 54   Ground defending duel                   Take on left, Lost, Not accurate
# 34               Head pass                                           Accurate
# 45  Ground loose ball duel                                      Won, Accurate
# 38  Ground loose ball duel                                 Lost, Not accurate
# 31            Acceleration                           Counter attack, Accurate
# 39                    Foul
# 32             Simple pass                           Counter attack, Accurate
# 27             Simple pass                   Assist, Counter attack, Accurate
# 35                    Shot  Goal, Counter attack, Left foot, Opportunity, ...
# 3                Goal kick
# 17            Acceleration                                           Accurate
# 18             Simple pass                                           Accurate
# 9    Ground defending duel               Free space right, Lost, Not accurate
# 23   Ground attacking duel                     Free space left, Won, Accurate
# 21               High pass                                           Accurate
# 22               Head pass                                           Accurate
# 16                   Touch                                              Feint
# 20   Ground attacking duel                   Anticipation, Lost, Not accurate
# 12   Ground defending duel                         Anticipated, Won, Accurate
# 13             Simple pass                                           Accurate
# 4              Simple pass                                           Accurate
# 14             Simple pass                                           Accurate
# 7                High pass                                           Accurate
# 11             Simple pass                                           Accurate
# 10             Simple pass                                           Accurate
# 5              Simple pass                                           Accurate
# 15             Simple pass                                           Accurate
# 8              Simple pass                                           Accurate
# 2              Simple pass                                           Accurate
# 0              Simple pass                                           Accurate
# 6          Free kick cross                             Assist, High, Accurate
# 19                Air duel                                 Lost, Not accurate
# 1                     Shot  Goal, Head/body, Opportunity, Position: Goal l...
#
#                       Match               Event     EventSec MatchPeriod  \
# 37  Uruguay - France, 0 - 2                Pass   888.784996          1H
# 36  Uruguay - France, 0 - 2                Shot   890.383366          1H
# 42  Uruguay - France, 0 - 2                Pass   911.317722          2H
# 28  Uruguay - France, 0 - 2                Pass   917.104962          2H
# 29  Uruguay - France, 0 - 2                Pass   920.558108          2H
# 49  Uruguay - France, 0 - 2                Duel   923.857204          2H
# 40  Uruguay - France, 0 - 2                Duel   923.882755          2H
# 26  Uruguay - France, 0 - 2                Pass   926.139298          2H
# 55  Uruguay - France, 0 - 2  Others on the ball   927.620581          2H
# 50  Uruguay - France, 0 - 2           Free Kick   928.264773          1H
# 56  Uruguay - France, 0 - 2                Pass   930.959616          2H
# 47  Uruguay - France, 0 - 2                Duel   931.678666          1H
# 43  Uruguay - France, 0 - 2                Duel   931.862696          2H
# 24  Uruguay - France, 0 - 2                Duel   931.899756          2H
# 48  Uruguay - France, 0 - 2                Duel   932.217111          1H
# 25  Uruguay - France, 0 - 2                Duel   932.249725          1H
# 57  Uruguay - France, 0 - 2                Duel   933.068363          2H
# 41  Uruguay - France, 0 - 2                Duel   933.365279          2H
# 58  Uruguay - France, 0 - 2                Pass   934.190860          2H
# 33  Uruguay - France, 0 - 2                Pass   934.408788          1H
# 44  Uruguay - France, 0 - 2                Pass   935.060937          2H
# 52  Uruguay - France, 0 - 2  Others on the ball   935.207443          2H
# 46  Uruguay - France, 0 - 2                Pass   936.077399          2H
# 51  Uruguay - France, 0 - 2                Pass   936.084704          1H
# 53  Uruguay - France, 0 - 2  Others on the ball   937.225753          2H
# 30  Uruguay - France, 0 - 2                Duel   938.453529          2H
# 54  Uruguay - France, 0 - 2                Duel   938.545362          2H
# 34  Uruguay - France, 0 - 2                Pass   938.779953          1H
# 45  Uruguay - France, 0 - 2                Duel   939.920563          1H
# 38  Uruguay - France, 0 - 2                Duel   940.518824          1H
# 31  Uruguay - France, 0 - 2  Others on the ball   940.924987          2H
# 39  Uruguay - France, 0 - 2                Foul   942.010991          1H
# 32  Uruguay - France, 0 - 2                Pass   943.411467          2H
# 27  Uruguay - France, 0 - 2                Pass   945.178696          2H
# 35  Uruguay - France, 0 - 2                Shot   947.251197          2H
# 3   Uruguay - France, 0 - 2           Free Kick  2320.721897          2H
# 17  Uruguay - France, 0 - 2  Others on the ball  2325.847246          2H
# 18  Uruguay - France, 0 - 2                Pass  2332.131581          2H
# 9   Uruguay - France, 0 - 2                Duel  2336.396119          2H
# 23  Uruguay - France, 0 - 2                Duel  2336.396119          2H
# 21  Uruguay - France, 0 - 2                Pass  2338.039978          2H
# 22  Uruguay - France, 0 - 2                Pass  2340.561882          2H
# 16  Uruguay - France, 0 - 2  Others on the ball  2341.154954          2H
# 20  Uruguay - France, 0 - 2                Duel  2342.024863          2H
# 12  Uruguay - France, 0 - 2                Duel  2342.497766          2H
# 13  Uruguay - France, 0 - 2                Pass  2344.637974          2H
# 4   Uruguay - France, 0 - 2                Pass  2349.990224          2H
# 14  Uruguay - France, 0 - 2                Pass  2351.602267          2H
# 7   Uruguay - France, 0 - 2                Pass  2354.427434          2H
# 11  Uruguay - France, 0 - 2                Pass  2358.009601          2H
# 10  Uruguay - France, 0 - 2                Pass  2360.745914          2H
# 5   Uruguay - France, 0 - 2                Pass  2364.709269          2H
# 15  Uruguay - France, 0 - 2                Pass  2366.115457          2H
# 8   Uruguay - France, 0 - 2                Pass  2366.999624          2H
# 2   Uruguay - France, 0 - 2                Pass  2368.981832          2H
# 0   Uruguay - France, 0 - 2                Pass  2369.418166          2H
# 6   Uruguay - France, 0 - 2           Free Kick  2369.447264          1H
# 19  Uruguay - France, 0 - 2                Duel  2370.574308          1H
# 1   Uruguay - France, 0 - 2                Shot  2370.699238          1H
#
#        Team             Player Position   Status
# 37   France          O. Giroud       CF     DRAW
# 36   France     K. Mbapp\u00e9       CF     DRAW
# 42  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 28   France          R. Varane       CB  LEADING
# 29   France          H. Lloris      GKP  LEADING
# 49  Uruguay    J. Gim\u00e9nez      NaN  LEADING
# 40   France          O. Giroud       CF  LEADING
# 26   France         C. Tolisso       CM  LEADING
# 55  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 50  Uruguay         F. Muslera      NaN     DRAW
# 56  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 47  Uruguay          C. Stuani      NaN     DRAW
# 43  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 24   France          B. Pavard       RB  LEADING
# 48  Uruguay          C. Stuani      NaN     DRAW
# 25   France         C. Tolisso       CM     DRAW
# 57  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 41   France          O. Giroud       CF  LEADING
# 58  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 33   France          S. Umtiti       CB     DRAW
# 44  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 52  Uruguay          M. Vecino      NaN  LEADING
# 46  Uruguay        L. Torreira      NaN  LEADING
# 51  Uruguay    M. C\u00e1ceres      NaN     DRAW
# 53  Uruguay          M. Vecino      NaN  LEADING
# 30   France           P. Pogba       CM  LEADING
# 54  Uruguay          M. Vecino      NaN  LEADING
# 34   France          S. Umtiti       CB     DRAW
# 45  Uruguay        L. Torreira      NaN     DRAW
# 38   France          O. Giroud       CF     DRAW
# 31   France           P. Pogba       CM  LEADING
# 39   France          O. Giroud       CF     DRAW
# 32   France           P. Pogba       CM  LEADING
# 27   France         C. Tolisso       CM  LEADING
# 35   France       A. Griezmann       AM  LEADING
# 3    France          H. Lloris      GKP  LEADING
# 17  Uruguay      D. God\u00edn      NaN  LEADING
# 18  Uruguay      D. God\u00edn      NaN  LEADING
# 9    France      N. Kant\u00e9      CDM  LEADING
# 23  Uruguay   J. Urretavizcaya      NaN  LEADING
# 21  Uruguay          M. Vecino      NaN  LEADING
# 22  Uruguay  C. Rodr\u00edguez      NaN  LEADING
# 16  Uruguay     L. Su\u00e1rez      NaN  LEADING
# 20  Uruguay    J. Gim\u00e9nez      NaN  LEADING
# 12   France         S. N'Zonzi       CM  LEADING
# 13   France         S. N'Zonzi       CM  LEADING
# 4    France           P. Pogba       CM  LEADING
# 14   France         S. N'Zonzi       CM  LEADING
# 7    France       A. Griezmann       AM  LEADING
# 11   France  L. Hern\u00e1ndez       LB  LEADING
# 10   France      N. Kant\u00e9      CDM  LEADING
# 5    France          S. Umtiti       CB  LEADING
# 15   France         S. N'Zonzi       CM  LEADING
# 8    France       A. Griezmann       AM  LEADING
# 2    France          R. Varane       CB  LEADING
# 0    France          B. Pavard       RB  LEADING
# 6    France       A. Griezmann       AM     DRAW
# 19  Uruguay          C. Stuani      NaN     DRAW
# 1    France          R. Varane       CB     DRAW

# %% [markdown]
# Belgium - France

# %%
events_belgium = events_before_goal_by_minutes(data, 'Belgium', minutes=1)
events_belgium
# Out:
#                  SubEvent                                               Tags  \
# 4             Simple pass                                           Accurate
# 14            Simple pass                                           Accurate
# 18            Simple pass                                           Accurate
# 5             Simple pass                                           Accurate
# 28            Simple pass                                           Accurate
# 2             Simple pass                                           Accurate
# 22            Simple pass                                           Accurate
# 1             Simple pass                                           Accurate
# 19            Simple pass                                           Accurate
# 31            Simple pass                                           Accurate
# 10            Simple pass                                           Accurate
# 16            Simple pass                                           Accurate
# 6             Simple pass                                           Accurate
# 20            Simple pass                                           Accurate
# 11            Simple pass                                           Accurate
# 29            Simple pass                                           Accurate
# 15            Simple pass                                           Accurate
# 21            Simple pass                                           Accurate
# 12  Ground attacking duel                    Free space right, Won, Accurate
# 30            Simple pass                                           Accurate
# 32  Ground defending duel                Free space left, Lost, Not accurate
# 13                   Shot     Right foot, Blocked, Opportunity, Not accurate
# 33                  Touch                                       Interception
# 23            Simple pass                                           Accurate
# 17            Simple pass                                           Accurate
# 25           Acceleration                                           Accurate
# 26  Ground attacking duel                     Free space left, Won, Accurate
# 0   Ground defending duel               Free space right, Lost, Not accurate
# 27                  Cross                            Left foot, Not accurate
# 3               Clearance                         Interception, Not accurate
# 9                  Corner                             Assist, High, Accurate
# 24               Air duel                                 Lost, Not accurate
# 7                Air duel                                      Won, Accurate
# 8                    Shot  Goal, Head/body, Opportunity, Position: Goal c...
#
#                       Match               Event    EventSec MatchPeriod  \
# 4   France - Belgium, 1 - 0                Pass  278.729058          2H
# 14  France - Belgium, 1 - 0                Pass  279.349046          2H
# 18  France - Belgium, 1 - 0                Pass  279.612385          1H
# 5   France - Belgium, 1 - 0                Pass  281.916241          2H
# 28  France - Belgium, 1 - 0                Pass  284.040891          1H
# 2   France - Belgium, 1 - 0                Pass  284.663701          2H
# 22  France - Belgium, 1 - 0                Pass  286.886017          1H
# 1   France - Belgium, 1 - 0                Pass  288.558720          2H
# 19  France - Belgium, 1 - 0                Pass  289.002488          1H
# 31  France - Belgium, 1 - 0                Pass  291.368585          1H
# 10  France - Belgium, 1 - 0                Pass  293.119569          2H
# 16  France - Belgium, 1 - 0                Pass  294.632442          1H
# 6   France - Belgium, 1 - 0                Pass  296.252103          2H
# 20  France - Belgium, 1 - 0                Pass  297.274627          1H
# 11  France - Belgium, 1 - 0                Pass  297.398289          2H
# 29  France - Belgium, 1 - 0                Pass  298.971027          1H
# 15  France - Belgium, 1 - 0                Pass  300.399799          2H
# 21  France - Belgium, 1 - 0                Pass  301.066569          1H
# 12  France - Belgium, 1 - 0                Duel  302.210310          2H
# 30  France - Belgium, 1 - 0                Pass  302.254197          1H
# 32  France - Belgium, 1 - 0                Duel  302.393239          2H
# 13  France - Belgium, 1 - 0                Shot  302.735838          2H
# 33  France - Belgium, 1 - 0  Others on the ball  303.951718          2H
# 23  France - Belgium, 1 - 0                Pass  306.251811          1H
# 17  France - Belgium, 1 - 0                Pass  309.813035          1H
# 25  France - Belgium, 1 - 0  Others on the ball  311.279173          1H
# 26  France - Belgium, 1 - 0                Duel  315.015227          1H
# 0   France - Belgium, 1 - 0                Duel  315.246159          1H
# 27  France - Belgium, 1 - 0                Pass  316.276382          1H
# 3   France - Belgium, 1 - 0  Others on the ball  317.821031          1H
# 9   France - Belgium, 1 - 0           Free Kick  334.496557          2H
# 24  France - Belgium, 1 - 0                Duel  335.240263          2H
# 7   France - Belgium, 1 - 0                Duel  335.640221          2H
# 8   France - Belgium, 1 - 0                Shot  336.270432          2H
#
#        Team             Player Position Status
# 4    France          S. Umtiti       CB   DRAW
# 14   France         B. Matuidi       LM   DRAW
# 18  Belgium    T. Alderweireld      NaN   DRAW
# 5    France          S. Umtiti       CB   DRAW
# 28  Belgium          N. Chadli      NaN   DRAW
# 2    France          H. Lloris      GKP   DRAW
# 22  Belgium          A. Witsel      NaN   DRAW
# 1    France          R. Varane       CB   DRAW
# 19  Belgium    T. Alderweireld      NaN   DRAW
# 31  Belgium         V. Kompany      NaN   DRAW
# 10   France      N. Kant\u00e9      CDM   DRAW
# 16  Belgium      J. Vertonghen      NaN   DRAW
# 6    France          S. Umtiti       CB   DRAW
# 20  Belgium    T. Alderweireld      NaN   DRAW
# 11   France  L. Hern\u00e1ndez       LB   DRAW
# 29  Belgium          N. Chadli      NaN   DRAW
# 15   France         B. Matuidi       LM   DRAW
# 21  Belgium       K. De Bruyne      NaN   DRAW
# 12   France          O. Giroud       CF   DRAW
# 30  Belgium          N. Chadli      NaN   DRAW
# 32  Belgium         V. Kompany      NaN   DRAW
# 13   France          O. Giroud       CF   DRAW
# 33  Belgium         V. Kompany      NaN   DRAW
# 23  Belgium          A. Witsel      NaN   DRAW
# 17  Belgium      J. Vertonghen      NaN   DRAW
# 25  Belgium          E. Hazard      NaN   DRAW
# 26  Belgium          E. Hazard      NaN   DRAW
# 0    France          B. Pavard       RB   DRAW
# 27  Belgium          E. Hazard      NaN   DRAW
# 3    France          S. Umtiti       CB   DRAW
# 9    France       A. Griezmann       AM   DRAW
# 24  Belgium        M. Fellaini      NaN   DRAW
# 7    France          S. Umtiti       CB   DRAW
# 8    France          S. Umtiti       CB   DRAW

# %% [markdown]
# France - Croatia

# %%
events_croatia = events_before_goal_by_minutes(data, 'Croatia', minutes=1)
events_croatia
# Out:
#                  SubEvent                                               Tags  \
# 18            Simple pass                                           Accurate
# 36              High pass                                           Accurate
# 0                Throw in                                           Accurate
# 2             Simple pass                                           Accurate
# 1   Ground defending duel               Free space right, Lost, Not accurate
# ..                    ...                                                ...
# 43           Acceleration                                           Accurate
# 44  Ground attacking duel                                      Won, Accurate
# 39  Ground defending duel                                 Lost, Not accurate
# 40                   Foul
# 41                Penalty  Goal, Left foot, Position: Goal low left, Accu...
#
#                       Match               Event     EventSec MatchPeriod  \
# 18  France - Croatia, 4 - 2                Pass   757.023568          2H
# 36  France - Croatia, 4 - 2                Pass   759.527872          2H
# 0   France - Croatia, 4 - 2           Free Kick   762.184378          1H
# 2   France - Croatia, 4 - 2                Pass   763.961485          1H
# 1   France - Croatia, 4 - 2                Duel   764.715880          2H
# ..                      ...                 ...          ...         ...
# 43  France - Croatia, 4 - 2  Others on the ball  2246.846443          2H
# 44  France - Croatia, 4 - 2                Duel  2248.822649          2H
# 39  France - Croatia, 4 - 2                Duel  2248.822649          2H
# 40  France - Croatia, 4 - 2                Foul  2251.097663          2H
# 41  France - Croatia, 4 - 2           Free Kick  2278.895744          1H
#
#        Team                  Player Position   Status
# 18  Croatia  M. Mand\u017euki\u0107      NaN  LEADING
# 36  Croatia           A. Rebi\u0107      NaN  LEADING
# 0    France               B. Pavard       RB     DRAW
# 2    France               R. Varane       CB     DRAW
# 1    France               B. Pavard       RB  LEADING
# ..      ...                     ...      ...      ...
# 43  Croatia         I. Rakiti\u0107      NaN  LEADING
# 44  Croatia         I. Rakiti\u0107      NaN  LEADING
# 39   France                P. Pogba       CM  LEADING
# 40   France                P. Pogba       CM  LEADING
# 41   France            A. Griezmann       AM     DRAW
#
# [139 rows x 10 columns]

# %% [markdown]
# France - Australia

# %%
events_australia = events_before_goal_by_minutes(data, 'Australia', minutes=1)
events_australia
# Out:
#                   SubEvent                                               Tags  \
# 21         Free kick cross                                     High, Accurate
# 23                Air duel                                 Lost, Not accurate
# 22                Air duel                                      Won, Accurate
# 24               Goal kick
# 25             Simple pass                                           Accurate
# 27             Simple pass                                           Accurate
# 26                 Penalty  Goal, Left foot, Position: Goal center right, ...
# 1              Simple pass                                           Accurate
# 5              Simple pass                                           Accurate
# 2              Simple pass                                           Accurate
# 12             Simple pass                                           Accurate
# 3                High pass                                       Not accurate
# 20             Simple pass                         Interception, Not accurate
# 7                 Throw in                                           Accurate
# 13                   Touch
# 16  Ground loose ball duel                                      Won, Accurate
# 14  Ground loose ball duel                                 Lost, Not accurate
# 17               Clearance                                       Not accurate
# 8                 Throw in                                           Accurate
# 10             Simple pass                                           Accurate
# 6              Simple pass                                           Accurate
# 0              Simple pass                                           Accurate
# 4              Simple pass                                           Accurate
# 15             Simple pass                                           Accurate
# 18   Ground defending duel                                 Lost, Not accurate
# 9    Ground attacking duel                                      Won, Accurate
# 19                    Foul
# 11                 Penalty  Goal, Right foot, Position: Goal low right, Ac...
#
#                         Match               Event    EventSec MatchPeriod  \
# 21  France - Australia, 2 - 1           Free Kick  708.701251          1H
# 23  France - Australia, 2 - 1                Duel  709.515309          1H
# 22  France - Australia, 2 - 1                Duel  709.779388          1H
# 24  France - Australia, 2 - 1           Free Kick  723.679940          1H
# 25  France - Australia, 2 - 1                Pass  725.832764          1H
# 27  France - Australia, 2 - 1                Pass  729.261904          1H
# 26  France - Australia, 2 - 1           Free Kick  730.009243          2H
# 1   France - Australia, 2 - 1                Pass  920.163658          1H
# 5   France - Australia, 2 - 1                Pass  921.747970          1H
# 2   France - Australia, 2 - 1                Pass  924.406751          1H
# 12  France - Australia, 2 - 1                Pass  927.852918          1H
# 3   France - Australia, 2 - 1                Pass  933.009144          1H
# 20  France - Australia, 2 - 1                Pass  935.031352          1H
# 7   France - Australia, 2 - 1           Free Kick  941.084149          1H
# 13  France - Australia, 2 - 1  Others on the ball  941.743235          1H
# 16  France - Australia, 2 - 1                Duel  942.830827          1H
# 14  France - Australia, 2 - 1                Duel  943.115339          1H
# 17  France - Australia, 2 - 1  Others on the ball  943.864251          1H
# 8   France - Australia, 2 - 1           Free Kick  946.369610          1H
# 10  France - Australia, 2 - 1                Pass  949.056735          1H
# 6   France - Australia, 2 - 1                Pass  951.887839          1H
# 0   France - Australia, 2 - 1                Pass  952.659922          1H
# 4   France - Australia, 2 - 1                Pass  954.661232          1H
# 15  France - Australia, 2 - 1                Pass  959.902215          1H
# 18  France - Australia, 2 - 1                Duel  960.675450          1H
# 9   France - Australia, 2 - 1                Duel  961.726300          1H
# 19  France - Australia, 2 - 1                Foul  963.258160          1H
# 11  France - Australia, 2 - 1           Free Kick  976.718211          2H
#
#          Team         Player Position   Status
# 21  Australia        A. Mooy      NaN     DRAW
# 23     France      B. Pavard       RB     DRAW
# 22  Australia      M. Leckie      NaN     DRAW
# 24     France      H. Lloris      GKP     DRAW
# 25     France      S. Umtiti       CB     DRAW
# 27     France  N. Kant\u00e9      CDM     DRAW
# 26     France   A. Griezmann       AM     DRAW
# 1   Australia    M. Milligan      NaN     DRAW
# 5   Australia        A. Mooy      NaN     DRAW
# 2   Australia    M. Milligan      NaN     DRAW
# 12  Australia      A. Behich      NaN     DRAW
# 3   Australia    M. Milligan      NaN     DRAW
# 20     France      R. Varane       CB     DRAW
# 7   Australia       R. Kruse      NaN     DRAW
# 13  Australia      A. Behich      NaN     DRAW
# 16     France      B. Pavard       RB     DRAW
# 14  Australia      A. Behich      NaN     DRAW
# 17     France      B. Pavard       RB     DRAW
# 8   Australia       R. Kruse      NaN     DRAW
# 10  Australia     M. Jedinak      NaN     DRAW
# 6   Australia        A. Mooy      NaN     DRAW
# 0   Australia   T. Sainsbury      NaN     DRAW
# 4   Australia    M. Milligan      NaN     DRAW
# 15  Australia      A. Behich      NaN     DRAW
# 18     France      B. Pavard       RB     DRAW
# 9   Australia       R. Kruse      NaN     DRAW
# 19     France      B. Pavard       RB     DRAW
# 11  Australia     M. Jedinak      NaN  LEADING

# %% [markdown]
# France - Peru

# %%
events_peru = events_before_goal_by_minutes(data, 'Peru', minutes=1)
events_peru
# Out:
#                   SubEvent                                               Tags  \
# 13  Ground loose ball duel                                      Won, Accurate
# 39  Ground loose ball duel                                 Lost, Not accurate
# 14             Simple pass                                           Accurate
# 25             Simple pass                                           Accurate
# 20             Simple pass                                           Accurate
# 31  Ground loose ball duel                 Sliding tackle, Lost, Not accurate
# 3                Free Kick                                           Accurate
# 7                High pass                        Key pass, Through, Accurate
# 18                    Shot  Right foot, Opportunity, Position: Goal center...
# 41                Reflexes                    Position: Goal center, Accurate
# 21             Simple pass                                           Accurate
# 10             Simple pass                                           Accurate
# 27   Ground defending duel                                  Neutral, Accurate
# 4                High pass                                           Accurate
# 0                    Touch
# 40             Simple pass                                           Accurate
# 38              Smart pass                              Through, Not accurate
# 37
# 28             Simple pass                                           Accurate
# 15   Ground defending duel                         Anticipated, Won, Accurate
# 33   Ground attacking duel                   Anticipation, Lost, Not accurate
# 16             Simple pass                                           Accurate
# 11            Acceleration                                           Accurate
# 12             Simple pass                                           Accurate
# 23             Simple pass                                           Accurate
# 26  Ground loose ball duel                      Sliding tackle, Won, Accurate
# 29             Simple pass                                           Accurate
# 1              Simple pass                                           Accurate
# 22             Simple pass                                           Accurate
# 34             Simple pass                                           Accurate
# 2              Simple pass                                           Accurate
# 32             Simple pass                                           Accurate
# 17             Simple pass                                           Accurate
# 35                   Touch
# 8   Ground loose ball duel                                      Won, Accurate
# 36  Ground loose ball duel                 Sliding tackle, Lost, Not accurate
# 5              Simple pass                                           Accurate
# 9               Smart pass                        Key pass, Through, Accurate
# 24                    Shot      Left foot, Blocked, Opportunity, Not accurate
# 6              Simple pass                                           Accurate
# 30                   Touch                                       Interception
# 19                    Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                    Match               Event     EventSec MatchPeriod    Team  \
# 13  France - Peru, 1 - 0                Duel  1965.524366          1H  France
# 39  France - Peru, 1 - 0                Duel  1966.549858          1H    Peru
# 14  France - Peru, 1 - 0                Pass  1967.647707          1H  France
# 25  France - Peru, 1 - 0                Pass  1969.370714          1H  France
# 20  France - Peru, 1 - 0                Pass  1971.975232          1H  France
# 31  France - Peru, 1 - 0                Duel  1972.539213          1H    Peru
# 3   France - Peru, 1 - 0           Free Kick  1976.809376          2H  France
# 7   France - Peru, 1 - 0                Pass  1977.211491          1H  France
# 18  France - Peru, 1 - 0                Shot  1978.651572          1H  France
# 41  France - Peru, 1 - 0        Save attempt  1980.363205          1H    Peru
# 21  France - Peru, 1 - 0                Pass  1981.219504          2H  France
# 10  France - Peru, 1 - 0                Pass  1982.981703          2H  France
# 27  France - Peru, 1 - 0                Duel  1983.389608          2H    Peru
# 4   France - Peru, 1 - 0                Pass  1987.580662          2H  France
# 0   France - Peru, 1 - 0  Others on the ball  1989.153821          2H  France
# 40  France - Peru, 1 - 0                Pass  1989.900686          2H    Peru
# 38  France - Peru, 1 - 0                Pass  1992.815445          2H    Peru
# 37  France - Peru, 1 - 0             Offside  1995.025677          2H    Peru
# 28  France - Peru, 1 - 0                Pass  2005.047435          1H    Peru
# 15  France - Peru, 1 - 0                Duel  2005.549289          1H  France
# 33  France - Peru, 1 - 0                Duel  2005.830183          1H    Peru
# 16  France - Peru, 1 - 0                Pass  2006.619300          1H  France
# 11  France - Peru, 1 - 0  Others on the ball  2008.080689          1H  France
# 12  France - Peru, 1 - 0                Pass  2010.527621          1H  France
# 23  France - Peru, 1 - 0                Pass  2011.249041          1H  France
# 26  France - Peru, 1 - 0                Duel  2012.546616          1H    Peru
# 29  France - Peru, 1 - 0                Pass  2013.813400          1H    Peru
# 1   France - Peru, 1 - 0                Pass  2013.882019          2H  France
# 22  France - Peru, 1 - 0                Pass  2016.049840          2H  France
# 34  France - Peru, 1 - 0                Pass  2017.342216          1H    Peru
# 2   France - Peru, 1 - 0                Pass  2017.971943          2H  France
# 32  France - Peru, 1 - 0                Pass  2018.321334          1H    Peru
# 17  France - Peru, 1 - 0                Pass  2018.504809          2H  France
# 35  France - Peru, 1 - 0  Others on the ball  2019.295633          1H    Peru
# 8   France - Peru, 1 - 0                Duel  2019.807640          1H  France
# 36  France - Peru, 1 - 0                Duel  2019.978058          1H    Peru
# 5   France - Peru, 1 - 0                Pass  2021.364305          2H  France
# 9   France - Peru, 1 - 0                Pass  2022.354070          1H  France
# 24  France - Peru, 1 - 0                Shot  2023.580214          1H  France
# 6   France - Peru, 1 - 0                Pass  2024.305789          2H  France
# 30  France - Peru, 1 - 0  Others on the ball  2024.690943          1H    Peru
# 19  France - Peru, 1 - 0                Shot  2025.334462          1H  France
#
#                   Player Position Status
# 13         N. Kant\u00e9      CDM   DRAW
# 39        \u00c9. Flores      NaN   DRAW
# 14         N. Kant\u00e9      CDM   DRAW
# 25            B. Matuidi       LM   DRAW
# 20     L. Hern\u00e1ndez       LB   DRAW
# 31     L. Adv\u00edncula      NaN   DRAW
# 3              R. Varane       CB   DRAW
# 7               P. Pogba       CM   DRAW
# 18        K. Mbapp\u00e9       CF   DRAW
# 41            P. Gallese      NaN   DRAW
# 21     L. Hern\u00e1ndez       LB   DRAW
# 10              P. Pogba       CM   DRAW
# 27             P. Aquino      NaN   DRAW
# 4              R. Varane       CB   DRAW
# 0              B. Pavard       RB   DRAW
# 40             M. Trauco      NaN   DRAW
# 38              C. Cueva      NaN   DRAW
# 37           P. Guerrero      NaN   DRAW
# 28     A. Rodr\u00edguez      NaN   DRAW
# 15         N. Kant\u00e9      CDM   DRAW
# 33           P. Guerrero      NaN   DRAW
# 16         N. Kant\u00e9      CDM   DRAW
# 11          A. Griezmann       AM   DRAW
# 12          A. Griezmann       AM   DRAW
# 23             O. Giroud       CF   DRAW
# 26         Y. Yot\u00fan      NaN   DRAW
# 29     A. Rodr\u00edguez      NaN   DRAW
# 1              B. Pavard       RB   DRAW
# 22  O. Demb\u00e9l\u00e9       RW   DRAW
# 34           P. Guerrero      NaN   DRAW
# 2              B. Pavard       RB   DRAW
# 32     L. Adv\u00edncula      NaN   DRAW
# 17         N. Kant\u00e9      CDM   DRAW
# 35           P. Guerrero      NaN   DRAW
# 8               P. Pogba       CM   DRAW
# 36           P. Guerrero      NaN   DRAW
# 5              R. Varane       CB   DRAW
# 9               P. Pogba       CM   DRAW
# 24             O. Giroud       CF   DRAW
# 6              H. Lloris      GKP   DRAW
# 30     A. Rodr\u00edguez      NaN   DRAW
# 19        K. Mbapp\u00e9       CF   DRAW

# %%
all_events_before_goals = pd.concat([events_argentina, events_uruguay, events_croatia, events_australia, events_belgium, events_peru], ignore_index=True)
all_events_before_goals
# Out:
#         SubEvent                                               Tags  \
# 0          Touch
# 1    Simple pass                                           Accurate
# 2    Simple pass                                           Accurate
# 3    Simple pass                                           Accurate
# 4      High pass                                           Accurate
# ..           ...                                                ...
# 501   Smart pass                        Key pass, Through, Accurate
# 502         Shot      Left foot, Blocked, Opportunity, Not accurate
# 503  Simple pass                                           Accurate
# 504        Touch                                       Interception
# 505         Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3  Others on the ball    98.151883          1H
# 1    France - Argentina, 4 - 3                Pass   101.848230          1H
# 2    France - Argentina, 4 - 3                Pass   103.005443          1H
# 3    France - Argentina, 4 - 3                Pass   104.546703          1H
# 4    France - Argentina, 4 - 3                Pass   106.237017          1H
# ..                         ...                 ...          ...         ...
# 501       France - Peru, 1 - 0                Pass  2022.354070          1H
# 502       France - Peru, 1 - 0                Shot  2023.580214          1H
# 503       France - Peru, 1 - 0                Pass  2024.305789          2H
# 504       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 505       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#           Team             Player Position Status
# 0    Argentina         G. Mercado      NaN   DRAW
# 1    Argentina         G. Mercado      NaN   DRAW
# 2    Argentina      C. Pav\u00f3n      NaN   DRAW
# 3    Argentina         G. Mercado      NaN   DRAW
# 4    Argentina        N. Otamendi      NaN   DRAW
# ..         ...                ...      ...    ...
# 501     France           P. Pogba       CM   DRAW
# 502     France          O. Giroud       CF   DRAW
# 503     France          H. Lloris      GKP   DRAW
# 504       Peru  A. Rodr\u00edguez      NaN   DRAW
# 505     France     K. Mbapp\u00e9       CF   DRAW
#
# [506 rows x 10 columns]

# %%
filtered_events = all_events_before_goals[
    ~(
        (all_events_before_goals['Event'] == 'Duel') & 
        (all_events_before_goals['Tags'].str.contains("Lost"))
    )
]

filtered_events
# Out:
#         SubEvent                                               Tags  \
# 0          Touch
# 1    Simple pass                                           Accurate
# 2    Simple pass                                           Accurate
# 3    Simple pass                                           Accurate
# 4      High pass                                           Accurate
# ..           ...                                                ...
# 501   Smart pass                        Key pass, Through, Accurate
# 502         Shot      Left foot, Blocked, Opportunity, Not accurate
# 503  Simple pass                                           Accurate
# 504        Touch                                       Interception
# 505         Shot  Goal, Right foot, Opportunity, Position: Goal ...
#
#                          Match               Event     EventSec MatchPeriod  \
# 0    France - Argentina, 4 - 3  Others on the ball    98.151883          1H
# 1    France - Argentina, 4 - 3                Pass   101.848230          1H
# 2    France - Argentina, 4 - 3                Pass   103.005443          1H
# 3    France - Argentina, 4 - 3                Pass   104.546703          1H
# 4    France - Argentina, 4 - 3                Pass   106.237017          1H
# ..                         ...                 ...          ...         ...
# 501       France - Peru, 1 - 0                Pass  2022.354070          1H
# 502       France - Peru, 1 - 0                Shot  2023.580214          1H
# 503       France - Peru, 1 - 0                Pass  2024.305789          2H
# 504       France - Peru, 1 - 0  Others on the ball  2024.690943          1H
# 505       France - Peru, 1 - 0                Shot  2025.334462          1H
#
#           Team             Player Position Status
# 0    Argentina         G. Mercado      NaN   DRAW
# 1    Argentina         G. Mercado      NaN   DRAW
# 2    Argentina      C. Pav\u00f3n      NaN   DRAW
# 3    Argentina         G. Mercado      NaN   DRAW
# 4    Argentina        N. Otamendi      NaN   DRAW
# ..         ...                ...      ...    ...
# 501     France           P. Pogba       CM   DRAW
# 502     France          O. Giroud       CF   DRAW
# 503     France          H. Lloris      GKP   DRAW
# 504       Peru  A. Rodr\u00edguez      NaN   DRAW
# 505     France     K. Mbapp\u00e9       CF   DRAW
#
# [451 rows x 10 columns]

# %%
all_events_before_goals['Match'].unique()
# Out:
# array(['France - Argentina, 4 - 3', 'Uruguay - France, 0 - 2',
#        'France - Croatia, 4 - 2', 'France - Australia, 2 - 1',
#        'France - Belgium, 1 - 0', 'France - Peru, 1 - 0'], dtype=object)

# %% [markdown]
# ##We have shot, freekick shot, cross , freekick cross, corner in subevent which are more exciting for now.

# %%
def sort_by_match(data):
    return data.sort_values(by=['Match','MatchPeriod', 'EventSec'])

all_events_before_goals_sorted = sort_by_match(all_events_before_goals)
filtered_events_sorted = sort_by_match(filtered_events)

# %% [markdown]
# We have finished our data preparation. Time to create an structured XES file

# %%
from datetime import datetime, timedelta

def create_non_filter_xes_file(data, filename="output.xes", checkOn :str = "org:resource"):

    def has_allowed_subevent(trace):
        return True

    def safe_str(value):
        """Safely convert value to string, handling NaN"""
        if pd.isna(value):
            return ""
        return str(value)

    base_datetime = datetime(2020, 1, 1) # Arbitrary date for the timestamp

    # Open file to write
    with open(filename, 'w') as f:
        # Write XML declaration and log opening tag
        f.write('<?xml version="1.0" encoding="UTF-8" ?>\n')
        f.write('<log xes.version="1.0" xes.features="nested-attributes" openxes.version="1.0RC7" xmlns="http://www.xes-standard.org/">\n')
        f.write(f'<classifier name="Activity_Resource" keys="{checkOn}"/>\n')
        f.write('<classifier name="Default" keys="concept:name"/>\n')
        
        # Initialize variables for tracking traces
        current_trace = []
        in_possession = False
        last_opponent_action = None  # To keep track of the last action by the opponent
        
        # Iterate over each row in the data
        for idx, row in data.iterrows():
            # Check if the team is "France"
            if row['Team'] == 'France':
                # Start a new trace if we're not in possession
                if not in_possession:
                    # If there was a previous trace, write it to the file
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            start_reason = last_opponent_action  # Set start reason to last opponent action
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = True
                
                # Add the current event to the trace
                current_trace.append({
                    'Player': row['Player'],
                    'Position': row['Position'],
                    'Event': row['Event'],
                    'EventSec': row['EventSec'],
                    'SubEvent': row['SubEvent'],
                    'MatchPeriod': row['MatchPeriod'],
                    'Tags': row['Tags'],
                    "Match": row['Match'],
                    "Status": row['Status']
                })
                
            else:
                # If team is not France, complete the current trace
                if in_possession:
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = False
                
                # Keep track of the last action of the opponent
                last_opponent_action = row['Event']  # Update the last opponent action
        
        # Close the remaining trace if still in possession
        if current_trace:
            # Only write trace if it contains an allowed subevent
            if has_allowed_subevent(current_trace):
                end_reason = current_trace[-1]['Event']
                start_reason = last_opponent_action  # Use last opponent action as start reason
                
                f.write('  <trace>\n')
                f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                
                # Write each event in the trace
                for event in current_trace:
                    event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                    event_timestamp = event_datetime.isoformat() 
                    f.write('    <event>\n')
                    f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                    f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                    f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                    f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                    f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                    f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                    f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                    f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                    f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                    f.write('    </event>\n')
                
                f.write('  </trace>\n')
        
        # Close log
        f.write('</log>\n')

# %%
from datetime import datetime, timedelta

def create_attack_xes_data(data, filename="output.xes", checkOn :str = "org:resource"):
    # Define the allowed subevents
    ALLOWED_SUBEVENTS = {
        "Shot",
        "Free kick shot",
        "Cross",
        "Free kick cross",
        "Corner"
    }

    def has_allowed_subevent(trace):
        """Check if any event in the trace has an allowed subevent"""
        for event in trace:
            subevent = event['SubEvent']
            # Check if subevent is NaN or not a string
            if pd.isna(subevent) or not isinstance(subevent, str):
                continue
                
            # Split subevents by space and check each one
            subevents = subevent.split(' ')
            if any(subevent in ALLOWED_SUBEVENTS for subevent in subevents):
                return True
        return False

    def safe_str(value):
        """Safely convert value to string, handling NaN"""
        if pd.isna(value):
            return ""
        return str(value)

    base_datetime = datetime(2020, 1, 1) # Arbitrary date for the timestamp

    # Open file to write
    with open(filename, 'w') as f:
        # Write XML declaration and log opening tag
        f.write('<?xml version="1.0" encoding="UTF-8" ?>\n')
        f.write('<log xes.version="1.0" xes.features="nested-attributes" openxes.version="1.0RC7" xmlns="http://www.xes-standard.org/">\n')
        f.write(f'<classifier name="Activity_Resource" keys="{checkOn}"/>\n')
        f.write('<classifier name="Default" keys="concept:name"/>\n')
        
        # Initialize variables for tracking traces
        current_trace = []
        in_possession = False
        last_opponent_action = None  # To keep track of the last action by the opponent
        
        # Iterate over each row in the data
        for idx, row in data.iterrows():
            # Check if the team is "France"
            if row['Team'] == 'France':
                # Start a new trace if we're not in possession
                if not in_possession:
                    # If there was a previous trace, write it to the file
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            start_reason = last_opponent_action  # Set start reason to last opponent action
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timestamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = True
                
                # Add the current event to the trace
                current_trace.append({
                    'Player': row['Player'],
                    'Position': row['Position'],
                    'Event': row['Event'],
                    'EventSec': row['EventSec'],
                    'SubEvent': row['SubEvent'],
                    'MatchPeriod': row['MatchPeriod'],
                    'Tags': row['Tags'],
                    "Match": row['Match'],
                    "Status": row['Status']
                })
                
            else:
                # If team is not France, complete the current trace
                if in_possession:
                    if current_trace:
                        # Only write trace if it contains an allowed subevent
                        if has_allowed_subevent(current_trace):
                            end_reason = current_trace[-1]['Event']
                            
                            # Write trace to file
                            f.write('  <trace>\n')
                            f.write(f'    <string key="custom:startReason" value="{safe_str(last_opponent_action)}" />\n')
                            f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                            
                            # Write each event in the trace
                            for event in current_trace:
                                event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                                event_timestamp = event_datetime.isoformat()  # ISO format for timestamp

                                f.write('    <event>\n')
                                f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                                f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                                f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                                f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                                f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                                f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                                f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                                f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                                f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                                f.write('    </event>\n')
                            
                            # Close trace
                            f.write('  </trace>\n')
                    
                    # Reset trace variables
                    current_trace = []
                    in_possession = False
                
                # Keep track of the last action of the opponent
                last_opponent_action = row['Event']  # Update the last opponent action
        
        # Close the remaining trace if still in possession
        if current_trace:
            # Only write trace if it contains an allowed subevent
            if has_allowed_subevent(current_trace):
                end_reason = current_trace[-1]['Event']
                start_reason = last_opponent_action  # Use last opponent action as start reason
                
                f.write('  <trace>\n')
                f.write(f'    <string key="custom:startReason" value="{safe_str(start_reason)}" />\n')
                f.write(f'    <string key="custom:endReason" value="{safe_str(end_reason)}" />\n')
                
                # Write each event in the trace
                for event in current_trace:
                    event_datetime = base_datetime + timedelta(seconds=event["EventSec"])
                    event_timestamp = event_datetime.isoformat() 
                    f.write('    <event>\n')
                    f.write(f'      <string key="org:resource" value="{safe_str(event["Position"])}" />\n')
                    f.write(f'      <string key="concept:name" value="{safe_str(event["Player"])}" />\n')
                    f.write(f'      <string key="custom:action" value="{safe_str(event["Event"])}" />\n')
                    f.write(f'      <date key="time:timeStamp" value="{event_timestamp}" />\n')
                    f.write(f'      <string key="custom:subevent" value="{safe_str(event["SubEvent"])}" />\n')
                    f.write(f'      <string key="custom:matchperiod" value="{safe_str(event["MatchPeriod"])}" />\n')
                    f.write(f'      <string key="custom:tags" value="{safe_str(event["Tags"])}" />\n')
                    f.write(f'      <string key="custom:match" value="{safe_str(event["Match"])}" />\n')
                    f.write(f'      <string key="custom:status" value="{event["Status"]}" />\n')

                    f.write('    </event>\n')
                
                f.write('  </trace>\n')
        
        # Close log
        f.write('</log>\n')

# %%
# vs_denmark = data[data['Match'].str.contains('Denmark - France', na=False)]
# create_attack_xes_data(sort_by_match(vs_denmark), filename="vs_denmark_attack.xes")
# create_non_filter_xes_file(sort_by_match(vs_denmark), filename="vs_denmark_all.xes")

create_non_filter_xes_file(all_events_before_goals_sorted, filename="all.xes")
create_attack_xes_data(all_events_before_goals_sorted, filename="all_attack.xes")

create_non_filter_xes_file(filtered_events_sorted, filename="filtered_all.xes")
create_attack_xes_data(filtered_events_sorted, filename="filtered_all_attack.xes")
